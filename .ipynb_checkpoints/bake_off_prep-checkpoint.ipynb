# %% [markdown]
# # NLP Bake-Off

# %%
import pickle
with open('speeches.pkl', 'rb') as f:
    speeches = pickle.load(f)

# %%
len(speeches)
# Out:
# 58

# %%
with open('target.pkl', 'rb') as f:
    target = pickle.load(f)

# %% [markdown]
# ## Consciously Splitting Speeches

# %%
train_indices = [1, 2, 3, 6, 7, 9, 11, 12, 13, 14, 17, 18,
                 21, 22, 23, 24, 28, 29, 30, 31, 34, 35, 36,
                 37, 39, 40, 41, 44, 45, 47, 48, 50, 51, 54,
                 55, 57]
test_indices = [0, 4, 5, 8, 10, 15, 16, 19, 20, 25, 26, 27,
                32, 33, 38, 42, 43, 46, 49, 52, 53, 56]

# %%
X_train = [speeches[j] for j in train_indices]
y_train = [target[j] for j in train_indices]

X_test = [speeches[j] for j in test_indices]
y_test = [target[j] for j in test_indices]

# %% [markdown]
# ## Preprocessing

# %%
import nltk

# %%
stem = nltk.stem.SnowballStemmer('english')

speeches_cleaned = [[stem.stem(word.lower())
                     for word in nltk.word_tokenize(speech.replace('\'', ''))]\
                     for speech in X_train]

# %%
speeches_cleaned
# Out:
# [['fellow',
#   'citizen',
#   ':',
#   'i',
#   'am',
#   'again',
#   'call',
#   'upon',
#   'by',
#   'the',
#   'voic',
#   'of',
#   'my',
#   'countri',
#   'to',
#   'execut',
#   'the',
#   'function',
#   'of',
#   'it',
#   'chief',
#   'magistr',
#   '.',
#   'when',
#   'the',
#   'occas',
#   'proper',
#   'for',
#   'it',
#   'shall',
#   'arriv',
#   ',',
#   'i',
#   'shall',
#   'endeavor',
#   'to',
#   'express',
#   'the',
#   'high',
#   'sens',
#   'i',
#   'entertain',
#   'of',
#   'this',
#   'distinguish',
#   'honor',
#   ',',
#   'and',
#   'of',
#   'the',
#   'confid',
#   'which',
#   'has',
#   'been',
#   'repos',
#   'in',
#   'me',
#   'by',
#   'the',
#   'peopl',
#   'of',
#   'unit',
#   'america',
#   '.',
#   'previous',
#   'to',
#   'the',
#   'execut',
#   'of',
#   'ani',
#   'offici',
#   'act',
#   'of',
#   'the',
#   'presid',
#   'the',
#   'constitut',
#   'requir',
#   'an',
#   'oath',
#   'of',
#   'offic',
#   '.',
#   'this',
#   'oath',
#   'i',
#   'am',
#   'now',
#   'about',
#   'to',
#   'take',
#   ',',
#   'and',
#   'in',
#   'your',
#   'presenc',
#   ':',
#   'that',
#   'if',
#   'it',
#   'shall',
#   'be',
#   'found',
#   'dure',
#   'my',
#   'administr',
#   'of',
#   'the',
#   'govern',
#   'i',
#   'have',
#   'in',
#   'ani',
#   'instanc',
#   'violat',
#   'will',
#   'or',
#   'know',
#   'the',
#   'injunct',
#   'thereof',
#   ',',
#   'i',
#   'may',
#   '(',
#   'besid',
#   'incur',
#   'constitut',
#   'punish',
#   ')',
#   'be',
#   'subject',
#   'to',
#   'the',
#   'upbraid',
#   'of',
#   'all',
#   'who',
#   'are',
#   'now',
#   'wit',
#   'of',
#   'the',
#   'present',
#   'solemn',
#   'ceremoni',
#   '.'],
#  ['when',
#   'it',
#   'was',
#   'first',
#   'perceiv',
#   ',',
#   'in',
#   'earli',
#   'time',
#   ',',
#   'that',
#   'no',
#   'middl',
#   'cours',
#   'for',
#   'america',
#   'remain',
#   'between',
#   'unlimit',
#   'submiss',
#   'to',
#   'a',
#   'foreign',
#   'legislatur',
#   'and',
#   'a',
#   'total',
#   'independ',
#   'of',
#   'it',
#   'claim',
#   ',',
#   'men',
#   'of',
#   'reflect',
#   'were',
#   'less',
#   'apprehens',
#   'of',
#   'danger',
#   'from',
#   'the',
#   'formid',
#   'power',
#   'of',
#   'fleet',
#   'and',
#   'armi',
#   'they',
#   'must',
#   'determin',
#   'to',
#   'resist',
#   'than',
#   'from',
#   'those',
#   'contest',
#   'and',
#   'dissens',
#   'which',
#   'would',
#   'certain',
#   'aris',
#   'concern',
#   'the',
#   'form',
#   'of',
#   'govern',
#   'to',
#   'be',
#   'institut',
#   'over',
#   'the',
#   'whole',
#   'and',
#   'over',
#   'the',
#   'part',
#   'of',
#   'this',
#   'extens',
#   'countri',
#   '.',
#   'reli',
#   ',',
#   'howev',
#   ',',
#   'on',
#   'the',
#   'puriti',
#   'of',
#   'their',
#   'intent',
#   ',',
#   'the',
#   'justic',
#   'of',
#   'their',
#   'caus',
#   ',',
#   'and',
#   'the',
#   'integr',
#   'and',
#   'intellig',
#   'of',
#   'the',
#   'peopl',
#   ',',
#   'under',
#   'an',
#   'overrul',
#   'provid',
#   'which',
#   'had',
#   'so',
#   'signal',
#   'protect',
#   'this',
#   'countri',
#   'from',
#   'the',
#   'first',
#   ',',
#   'the',
#   'repres',
#   'of',
#   'this',
#   'nation',
#   ',',
#   'then',
#   'consist',
#   'of',
#   'littl',
#   'more',
#   'than',
#   'half',
#   'it',
#   'present',
#   'number',
#   ',',
#   'not',
#   'onli',
#   'broke',
#   'to',
#   'piec',
#   'the',
#   'chain',
#   'which',
#   'were',
#   'forg',
#   'and',
#   'the',
#   'rod',
#   'of',
#   'iron',
#   'that',
#   'was',
#   'lift',
#   'up',
#   ',',
#   'but',
#   'frank',
#   'cut',
#   'asund',
#   'the',
#   'tie',
#   'which',
#   'had',
#   'bound',
#   'them',
#   ',',
#   'and',
#   'launch',
#   'into',
#   'an',
#   'ocean',
#   'of',
#   'uncertainti',
#   '.',
#   'the',
#   'zeal',
#   'and',
#   'ardor',
#   'of',
#   'the',
#   'peopl',
#   'dure',
#   'the',
#   'revolutionari',
#   'war',
#   ',',
#   'suppli',
#   'the',
#   'place',
#   'of',
#   'govern',
#   ',',
#   'command',
#   'a',
#   'degre',
#   'of',
#   'order',
#   'suffici',
#   'at',
#   'least',
#   'for',
#   'the',
#   'temporari',
#   'preserv',
#   'of',
#   'societi',
#   '.',
#   'the',
#   'confeder',
#   'which',
#   'was',
#   'earli',
#   'felt',
#   'to',
#   'be',
#   'necessari',
#   'was',
#   'prepar',
#   'from',
#   'the',
#   'model',
#   'of',
#   'the',
#   'batavian',
#   'and',
#   'helvet',
#   'confederaci',
#   ',',
#   'the',
#   'onli',
#   'exampl',
#   'which',
#   'remain',
#   'with',
#   'ani',
#   'detail',
#   'and',
#   'precis',
#   'in',
#   'histori',
#   ',',
#   'and',
#   'certain',
#   'the',
#   'onli',
#   'one',
#   'which',
#   'the',
#   'peopl',
#   'at',
#   'larg',
#   'had',
#   'ever',
#   'consid',
#   '.',
#   'but',
#   'reflect',
#   'on',
#   'the',
#   'strike',
#   'differ',
#   'in',
#   'so',
#   'mani',
#   'particular',
#   'between',
#   'this',
#   'countri',
#   'and',
#   'those',
#   'where',
#   'a',
#   'courier',
#   'may',
#   'go',
#   'from',
#   'the',
#   'seat',
#   'of',
#   'govern',
#   'to',
#   'the',
#   'frontier',
#   'in',
#   'a',
#   'singl',
#   'day',
#   ',',
#   'it',
#   'was',
#   'then',
#   'certain',
#   'foreseen',
#   'by',
#   'some',
#   'who',
#   'assist',
#   'in',
#   'congress',
#   'at',
#   'the',
#   'format',
#   'of',
#   'it',
#   'that',
#   'it',
#   'could',
#   'not',
#   'be',
#   'durabl',
#   '.',
#   'neglig',
#   'of',
#   'it',
#   'regul',
#   ',',
#   'inattent',
#   'to',
#   'it',
#   'recommend',
#   ',',
#   'if',
#   'not',
#   'disobedi',
#   'to',
#   'it',
#   'author',
#   ',',
#   'not',
#   'onli',
#   'in',
#   'individu',
#   'but',
#   'in',
#   'state',
#   ',',
#   'soon',
#   'appear',
#   'with',
#   'their',
#   'melancholi',
#   'consequ',
#   '?',
#   'univers',
#   'languor',
#   ',',
#   'jealousi',
#   'and',
#   'rivalri',
#   'of',
#   'state',
#   ',',
#   'declin',
#   'of',
#   'navig',
#   'and',
#   'commerc',
#   ',',
#   'discourag',
#   'of',
#   'necessari',
#   'manufactur',
#   ',',
#   'univers',
#   'fall',
#   'in',
#   'the',
#   'valu',
#   'of',
#   'land',
#   'and',
#   'their',
#   'produc',
#   ',',
#   'contempt',
#   'of',
#   'public',
#   'and',
#   'privat',
#   'faith',
#   ',',
#   'loss',
#   'of',
#   'consider',
#   'and',
#   'credit',
#   'with',
#   'foreign',
#   'nation',
#   ',',
#   'and',
#   'at',
#   'length',
#   'in',
#   'discont',
#   ',',
#   'animos',
#   ',',
#   'combin',
#   ',',
#   'partial',
#   'convent',
#   ',',
#   'and',
#   'insurrect',
#   ',',
#   'threaten',
#   'some',
#   'great',
#   'nation',
#   'calam',
#   '.',
#   'in',
#   'this',
#   'danger',
#   'crisi',
#   'the',
#   'peopl',
#   'of',
#   'america',
#   'were',
#   'not',
#   'abandon',
#   'by',
#   'their',
#   'usual',
#   'good',
#   'sens',
#   ',',
#   'presenc',
#   'of',
#   'mind',
#   ',',
#   'resolut',
#   ',',
#   'or',
#   'integr',
#   '.',
#   'measur',
#   'were',
#   'pursu',
#   'to',
#   'concert',
#   'a',
#   'plan',
#   'to',
#   'form',
#   'a',
#   'more',
#   'perfect',
#   'union',
#   ',',
#   'establish',
#   'justic',
#   ',',
#   'insur',
#   'domest',
#   'tranquil',
#   ',',
#   'provid',
#   'for',
#   'the',
#   'common',
#   'defens',
#   ',',
#   'promot',
#   'the',
#   'general',
#   'welfar',
#   ',',
#   'and',
#   'secur',
#   'the',
#   'bless',
#   'of',
#   'liberti',
#   '.',
#   'the',
#   'public',
#   'disquisit',
#   ',',
#   'discuss',
#   ',',
#   'and',
#   'deliber',
#   'issu',
#   'in',
#   'the',
#   'present',
#   'happi',
#   'constitut',
#   'of',
#   'govern',
#   '.',
#   'employ',
#   'in',
#   'the',
#   'servic',
#   'of',
#   'my',
#   'countri',
#   'abroad',
#   'dure',
#   'the',
#   'whole',
#   'cours',
#   'of',
#   'these',
#   'transact',
#   ',',
#   'i',
#   'first',
#   'saw',
#   'the',
#   'constitut',
#   'of',
#   'the',
#   'unit',
#   'state',
#   'in',
#   'a',
#   'foreign',
#   'countri',
#   '.',
#   'irrit',
#   'by',
#   'no',
#   'literari',
#   'alterc',
#   ',',
#   'anim',
#   'by',
#   'no',
#   'public',
#   'debat',
#   ',',
#   'heat',
#   'by',
#   'no',
#   'parti',
#   'animos',
#   ',',
#   'i',
#   'read',
#   'it',
#   'with',
#   'great',
#   'satisfact',
#   ',',
#   'as',
#   'the',
#   'result',
#   'of',
#   'good',
#   'head',
#   'prompt',
#   'by',
#   'good',
#   'heart',
#   ',',
#   'as',
#   'an',
#   'experi',
#   'better',
#   'adapt',
#   'to',
#   'the',
#   'genius',
#   ',',
#   'charact',
#   ',',
#   'situat',
#   ',',
#   'and',
#   'relat',
#   'of',
#   'this',
#   'nation',
#   'and',
#   'countri',
#   'than',
#   'ani',
#   'which',
#   'had',
#   'ever',
#   'been',
#   'propos',
#   'or',
#   'suggest',
#   '.',
#   'in',
#   'it',
#   'general',
#   'principl',
#   'and',
#   'great',
#   'outlin',
#   'it',
#   'was',
#   'conform',
#   'to',
#   'such',
#   'a',
#   'system',
#   'of',
#   'govern',
#   'as',
#   'i',
#   'had',
#   'ever',
#   'most',
#   'esteem',
#   ',',
#   'and',
#   'in',
#   'some',
#   'state',
#   ',',
#   'my',
#   'own',
#   'nativ',
#   'state',
#   'in',
#   'particular',
#   ',',
#   'had',
#   'contribut',
#   'to',
#   'establish',
#   '.',
#   'claim',
#   'a',
#   'right',
#   'of',
#   'suffrag',
#   ',',
#   'in',
#   'common',
#   'with',
#   'my',
#   'fellow-citizen',
#   ',',
#   'in',
#   'the',
#   'adopt',
#   'or',
#   'reject',
#   'of',
#   'a',
#   'constitut',
#   'which',
#   'was',
#   'to',
#   'rule',
#   'me',
#   'and',
#   'my',
#   'poster',
#   ',',
#   'as',
#   'well',
#   'as',
#   'them',
#   'and',
#   'their',
#   ',',
#   'i',
#   'did',
#   'not',
#   'hesit',
#   'to',
#   'express',
#   'my',
#   'approb',
#   'of',
#   'it',
#   'on',
#   'all',
#   'occas',
#   ',',
#   'in',
#   'public',
#   'and',
#   'in',
#   'privat',
#   '.',
#   'it',
#   'was',
#   'not',
#   'then',
#   ',',
#   'nor',
#   'has',
#   'been',
#   'sinc',
#   ',',
#   'ani',
#   'object',
#   'to',
#   'it',
#   'in',
#   'my',
#   'mind',
#   'that',
#   'the',
#   'execut',
#   'and',
#   'senat',
#   'were',
#   'not',
#   'more',
#   'perman',
#   '.',
#   'nor',
#   'have',
#   'i',
#   'ever',
#   'entertain',
#   'a',
#   'thought',
#   'of',
#   'promot',
#   'ani',
#   'alter',
#   'in',
#   'it',
#   'but',
#   'such',
#   'as',
#   'the',
#   'peopl',
#   'themselv',
#   ',',
#   'in',
#   'the',
#   'cours',
#   'of',
#   'their',
#   'experi',
#   ',',
#   'should',
#   'see',
#   'and',
#   'feel',
#   'to',
#   'be',
#   'necessari',
#   'or',
#   'expedi',
#   ',',
#   'and',
#   'by',
#   'their',
#   'repres',
#   'in',
#   'congress',
#   'and',
#   'the',
#   'state',
#   'legislatur',
#   ',',
#   'accord',
#   'to',
#   'the',
#   'constitut',
#   'itself',
#   ',',
#   'adopt',
#   'and',
#   'ordain',
#   '.',
#   'return',
#   'to',
#   'the',
#   'bosom',
#   'of',
#   'my',
#   'countri',
#   'after',
#   'a',
#   'pain',
#   'separ',
#   'from',
#   'it',
#   'for',
#   'ten',
#   'year',
#   ',',
#   'i',
#   'had',
#   'the',
#   'honor',
#   'to',
#   'be',
#   'elect',
#   'to',
#   'a',
#   'station',
#   'under',
#   'the',
#   'new',
#   'order',
#   'of',
#   'thing',
#   ',',
#   'and',
#   'i',
#   'have',
#   'repeat',
#   'laid',
#   'myself',
#   'under',
#   'the',
#   'most',
#   'serious',
#   'oblig',
#   'to',
#   'support',
#   'the',
#   'constitut',
#   '.',
#   'the',
#   'oper',
#   'of',
#   'it',
#   'has',
#   'equal',
#   'the',
#   'most',
#   'sanguin',
#   'expect',
#   'of',
#   'it',
#   'friend',
#   ',',
#   'and',
#   'from',
#   'an',
#   'habitu',
#   'attent',
#   'to',
#   'it',
#   ',',
#   'satisfact',
#   'in',
#   'it',
#   'administr',
#   ',',
#   'and',
#   'delight',
#   'in',
#   'it',
#   'effect',
#   'upon',
#   'the',
#   'peac',
#   ',',
#   'order',
#   ',',
#   'prosper',
#   ',',
#   'and',
#   'happi',
#   'of',
#   'the',
#   'nation',
#   'i',
#   'have',
#   'acquir',
#   'an',
#   'habitu',
#   'attach',
#   'to',
#   'it',
#   'and',
#   'vener',
#   'for',
#   'it',
#   '.',
#   'what',
#   'other',
#   'form',
#   'of',
#   'govern',
#   ',',
#   'inde',
#   ',',
#   'can',
#   'so',
#   'well',
#   'deserv',
#   'our',
#   'esteem',
#   'and',
#   'love',
#   '?',
#   'there',
#   'may',
#   'be',
#   'littl',
#   'solid',
#   'in',
#   'an',
#   'ancient',
#   'idea',
#   'that',
#   'congreg',
#   'of',
#   'men',
#   'into',
#   'citi',
#   'and',
#   'nation',
#   'are',
#   'the',
#   'most',
#   'pleas',
#   'object',
#   'in',
#   'the',
#   'sight',
#   'of',
#   'superior',
#   'intellig',
#   ',',
#   'but',
#   'this',
#   'is',
#   'veri',
#   'certain',
#   ',',
#   'that',
#   'to',
#   'a',
#   'benevol',
#   'human',
#   'mind',
#   'there',
#   'can',
#   'be',
#   'no',
#   'spectacl',
#   'present',
#   'by',
#   'ani',
#   'nation',
#   'more',
#   'pleas',
#   ',',
#   'more',
#   'nobl',
#   ',',
#   'majest',
#   ',',
#   'or',
#   'august',
#   ',',
#   'than',
#   'an',
#   'assembl',
#   'like',
#   'that',
#   'which',
#   'has',
#   'so',
#   'often',
#   'been',
#   'seen',
#   'in',
#   'this',
#   'and',
#   'the',
#   'other',
#   'chamber',
#   'of',
#   'congress',
#   ',',
#   'of',
#   'a',
#   'govern',
#   'in',
#   'which',
#   'the',
#   'execut',
#   'author',
#   ',',
#   'as',
#   'well',
#   'as',
#   'that',
#   'of',
#   'all',
#   'the',
#   'branch',
#   ...],
#  ['call',
#   'upon',
#   'to',
#   'undertak',
#   'the',
#   'duti',
#   'of',
#   'the',
#   'first',
#   'execut',
#   'offic',
#   'of',
#   'our',
#   'countri',
#   ',',
#   'i',
#   'avail',
#   'myself',
#   'of',
#   'the',
#   'presenc',
#   'of',
#   'that',
#   'portion',
#   'of',
#   'my',
#   'fellow-citizen',
#   'which',
#   'is',
#   'here',
#   'assembl',
#   'to',
#   'express',
#   'my',
#   'grate',
#   'thank',
#   'for',
#   'the',
#   'favor',
#   'with',
#   'which',
#   'they',
#   'have',
#   'been',
#   'pleas',
#   'to',
#   'look',
#   'toward',
#   'me',
#   ',',
#   'to',
#   'declar',
#   'a',
#   'sincer',
#   'conscious',
#   'that',
#   'the',
#   'task',
#   'is',
#   'abov',
#   'my',
#   'talent',
#   ',',
#   'and',
#   'that',
#   'i',
#   'approach',
#   'it',
#   'with',
#   'those',
#   'anxious',
#   'and',
#   'aw',
#   'presenti',
#   'which',
#   'the',
#   'great',
#   'of',
#   'the',
#   'charg',
#   'and',
#   'the',
#   'weak',
#   'of',
#   'my',
#   'power',
#   'so',
#   'just',
#   'inspir',
#   '.',
#   'a',
#   'rise',
#   'nation',
#   ',',
#   'spread',
#   'over',
#   'a',
#   'wide',
#   'and',
#   'fruit',
#   'land',
#   ',',
#   'travers',
#   'all',
#   'the',
#   'sea',
#   'with',
#   'the',
#   'rich',
#   'product',
#   'of',
#   'their',
#   'industri',
#   ',',
#   'engag',
#   'in',
#   'commerc',
#   'with',
#   'nation',
#   'who',
#   'feel',
#   'power',
#   'and',
#   'forget',
#   'right',
#   ',',
#   'advanc',
#   'rapid',
#   'to',
#   'destini',
#   'beyond',
#   'the',
#   'reach',
#   'of',
#   'mortal',
#   'eye',
#   '--',
#   'when',
#   'i',
#   'contempl',
#   'these',
#   'transcend',
#   'object',
#   ',',
#   'and',
#   'see',
#   'the',
#   'honor',
#   ',',
#   'the',
#   'happi',
#   ',',
#   'and',
#   'the',
#   'hope',
#   'of',
#   'this',
#   'belov',
#   'countri',
#   'commit',
#   'to',
#   'the',
#   'issu',
#   'and',
#   'the',
#   'auspic',
#   'of',
#   'this',
#   'day',
#   ',',
#   'i',
#   'shrink',
#   'from',
#   'the',
#   'contempl',
#   ',',
#   'and',
#   'humbl',
#   'myself',
#   'befor',
#   'the',
#   'magnitud',
#   'of',
#   'the',
#   'undertak',
#   '.',
#   'utter',
#   ',',
#   'inde',
#   ',',
#   'should',
#   'i',
#   'despair',
#   'did',
#   'not',
#   'the',
#   'presenc',
#   'of',
#   'mani',
#   'whom',
#   'i',
#   'here',
#   'see',
#   'remind',
#   'me',
#   'that',
#   'in',
#   'the',
#   'other',
#   'high',
#   'author',
#   'provid',
#   'by',
#   'our',
#   'constitut',
#   'i',
#   'shall',
#   'find',
#   'resourc',
#   'of',
#   'wisdom',
#   ',',
#   'of',
#   'virtu',
#   ',',
#   'and',
#   'of',
#   'zeal',
#   'on',
#   'which',
#   'to',
#   'reli',
#   'under',
#   'all',
#   'difficulti',
#   '.',
#   'to',
#   'you',
#   ',',
#   'then',
#   ',',
#   'gentlemen',
#   ',',
#   'who',
#   'are',
#   'charg',
#   'with',
#   'the',
#   'sovereign',
#   'function',
#   'of',
#   'legisl',
#   ',',
#   'and',
#   'to',
#   'those',
#   'associ',
#   'with',
#   'you',
#   ',',
#   'i',
#   'look',
#   'with',
#   'encourag',
#   'for',
#   'that',
#   'guidanc',
#   'and',
#   'support',
#   'which',
#   'may',
#   'enabl',
#   'us',
#   'to',
#   'steer',
#   'with',
#   'safeti',
#   'the',
#   'vessel',
#   'in',
#   'which',
#   'we',
#   'are',
#   'all',
#   'embark',
#   'amidst',
#   'the',
#   'conflict',
#   'element',
#   'of',
#   'a',
#   'troubl',
#   'world',
#   '.',
#   'dure',
#   'the',
#   'contest',
#   'of',
#   'opinion',
#   'through',
#   'which',
#   'we',
#   'have',
#   'pass',
#   'the',
#   'anim',
#   'of',
#   'discuss',
#   'and',
#   'of',
#   'exert',
#   'has',
#   'sometim',
#   'worn',
#   'an',
#   'aspect',
#   'which',
#   'might',
#   'impos',
#   'on',
#   'stranger',
#   'unus',
#   'to',
#   'think',
#   'freeli',
#   'and',
#   'to',
#   'speak',
#   'and',
#   'to',
#   'write',
#   'what',
#   'they',
#   'think',
#   ';',
#   'but',
#   'this',
#   'be',
#   'now',
#   'decid',
#   'by',
#   'the',
#   'voic',
#   'of',
#   'the',
#   'nation',
#   ',',
#   'announc',
#   'accord',
#   'to',
#   'the',
#   'rule',
#   'of',
#   'the',
#   'constitut',
#   ',',
#   'all',
#   'will',
#   ',',
#   'of',
#   'cours',
#   ',',
#   'arrang',
#   'themselv',
#   'under',
#   'the',
#   'will',
#   'of',
#   'the',
#   'law',
#   ',',
#   'and',
#   'unit',
#   'in',
#   'common',
#   'effort',
#   'for',
#   'the',
#   'common',
#   'good',
#   '.',
#   'all',
#   ',',
#   'too',
#   ',',
#   'will',
#   'bear',
#   'in',
#   'mind',
#   'this',
#   'sacr',
#   'principl',
#   ',',
#   'that',
#   'though',
#   'the',
#   'will',
#   'of',
#   'the',
#   'major',
#   'is',
#   'in',
#   'all',
#   'case',
#   'to',
#   'prevail',
#   ',',
#   'that',
#   'will',
#   'to',
#   'be',
#   'right',
#   'must',
#   'be',
#   'reason',
#   ';',
#   'that',
#   'the',
#   'minor',
#   'possess',
#   'their',
#   'equal',
#   'right',
#   ',',
#   'which',
#   'equal',
#   'law',
#   'must',
#   'protect',
#   ',',
#   'and',
#   'to',
#   'violat',
#   'would',
#   'be',
#   'oppress',
#   '.',
#   'let',
#   'us',
#   ',',
#   'then',
#   ',',
#   'fellow-citizen',
#   ',',
#   'unit',
#   'with',
#   'one',
#   'heart',
#   'and',
#   'one',
#   'mind',
#   '.',
#   'let',
#   'us',
#   'restor',
#   'to',
#   'social',
#   'intercours',
#   'that',
#   'harmoni',
#   'and',
#   'affect',
#   'without',
#   'which',
#   'liberti',
#   'and',
#   'even',
#   'life',
#   'itself',
#   'are',
#   'but',
#   'dreari',
#   'thing',
#   '.',
#   'and',
#   'let',
#   'us',
#   'reflect',
#   'that',
#   ',',
#   'have',
#   'banish',
#   'from',
#   'our',
#   'land',
#   'that',
#   'religi',
#   'intoler',
#   'under',
#   'which',
#   'mankind',
#   'so',
#   'long',
#   'bled',
#   'and',
#   'suffer',
#   ',',
#   'we',
#   'have',
#   'yet',
#   'gain',
#   'littl',
#   'if',
#   'we',
#   'counten',
#   'a',
#   'polit',
#   'intoler',
#   'as',
#   'despot',
#   ',',
#   'as',
#   'wick',
#   ',',
#   'and',
#   'capabl',
#   'of',
#   'as',
#   'bitter',
#   'and',
#   'bloodi',
#   'persecut',
#   '.',
#   'dure',
#   'the',
#   'throe',
#   'and',
#   'convuls',
#   'of',
#   'the',
#   'ancient',
#   'world',
#   ',',
#   'dure',
#   'the',
#   'agon',
#   'spasm',
#   'of',
#   'infuri',
#   'man',
#   ',',
#   'seek',
#   'through',
#   'blood',
#   'and',
#   'slaughter',
#   'his',
#   'long-lost',
#   'liberti',
#   ',',
#   'it',
#   'was',
#   'not',
#   'wonder',
#   'that',
#   'the',
#   'agit',
#   'of',
#   'the',
#   'billow',
#   'should',
#   'reach',
#   'even',
#   'this',
#   'distant',
#   'and',
#   'peac',
#   'shore',
#   ';',
#   'that',
#   'this',
#   'should',
#   'be',
#   'more',
#   'felt',
#   'and',
#   'fear',
#   'by',
#   'some',
#   'and',
#   'less',
#   'by',
#   'other',
#   ',',
#   'and',
#   'should',
#   'divid',
#   'opinion',
#   'as',
#   'to',
#   'measur',
#   'of',
#   'safeti',
#   '.',
#   'but',
#   'everi',
#   'differ',
#   'of',
#   'opinion',
#   'is',
#   'not',
#   'a',
#   'differ',
#   'of',
#   'principl',
#   '.',
#   'we',
#   'have',
#   'call',
#   'by',
#   'differ',
#   'name',
#   'brethren',
#   'of',
#   'the',
#   'same',
#   'principl',
#   '.',
#   'we',
#   'are',
#   'all',
#   'republican',
#   ',',
#   'we',
#   'are',
#   'all',
#   'federalist',
#   '.',
#   'if',
#   'there',
#   'be',
#   'ani',
#   'among',
#   'us',
#   'who',
#   'would',
#   'wish',
#   'to',
#   'dissolv',
#   'this',
#   'union',
#   'or',
#   'to',
#   'chang',
#   'it',
#   'republican',
#   'form',
#   ',',
#   'let',
#   'them',
#   'stand',
#   'undisturb',
#   'as',
#   'monument',
#   'of',
#   'the',
#   'safeti',
#   'with',
#   'which',
#   'error',
#   'of',
#   'opinion',
#   'may',
#   'be',
#   'toler',
#   'where',
#   'reason',
#   'is',
#   'left',
#   'free',
#   'to',
#   'combat',
#   'it',
#   '.',
#   'i',
#   'know',
#   ',',
#   'inde',
#   ',',
#   'that',
#   'some',
#   'honest',
#   'men',
#   'fear',
#   'that',
#   'a',
#   'republican',
#   'govern',
#   'can',
#   'not',
#   'be',
#   'strong',
#   ',',
#   'that',
#   'this',
#   'govern',
#   'is',
#   'not',
#   'strong',
#   'enough',
#   ';',
#   'but',
#   'would',
#   'the',
#   'honest',
#   'patriot',
#   ',',
#   'in',
#   'the',
#   'full',
#   'tide',
#   'of',
#   'success',
#   'experi',
#   ',',
#   'abandon',
#   'a',
#   'govern',
#   'which',
#   'has',
#   'so',
#   'far',
#   'kept',
#   'us',
#   'free',
#   'and',
#   'firm',
#   'on',
#   'the',
#   'theoret',
#   'and',
#   'visionari',
#   'fear',
#   'that',
#   'this',
#   'govern',
#   ',',
#   'the',
#   'world',
#   'best',
#   'hope',
#   ',',
#   'may',
#   'by',
#   'possibl',
#   'want',
#   'energi',
#   'to',
#   'preserv',
#   'itself',
#   '?',
#   'i',
#   'trust',
#   'not',
#   '.',
#   'i',
#   'believ',
#   'this',
#   ',',
#   'on',
#   'the',
#   'contrari',
#   ',',
#   'the',
#   'strongest',
#   'govern',
#   'on',
#   'earth',
#   '.',
#   'i',
#   'believ',
#   'it',
#   'the',
#   'onli',
#   'one',
#   'where',
#   'everi',
#   'man',
#   ',',
#   'at',
#   'the',
#   'call',
#   'of',
#   'the',
#   'law',
#   ',',
#   'would',
#   'fli',
#   'to',
#   'the',
#   'standard',
#   'of',
#   'the',
#   'law',
#   ',',
#   'and',
#   'would',
#   'meet',
#   'invas',
#   'of',
#   'the',
#   'public',
#   'order',
#   'as',
#   'his',
#   'own',
#   'person',
#   'concern',
#   '.',
#   'sometim',
#   'it',
#   'is',
#   'said',
#   'that',
#   'man',
#   'can',
#   'not',
#   'be',
#   'trust',
#   'with',
#   'the',
#   'govern',
#   'of',
#   'himself',
#   '.',
#   'can',
#   'he',
#   ',',
#   'then',
#   ',',
#   'be',
#   'trust',
#   'with',
#   'the',
#   'govern',
#   'of',
#   'other',
#   '?',
#   'or',
#   'have',
#   'we',
#   'found',
#   'angel',
#   'in',
#   'the',
#   'form',
#   'of',
#   'king',
#   'to',
#   'govern',
#   'him',
#   '?',
#   'let',
#   'histori',
#   'answer',
#   'this',
#   'question',
#   '.',
#   'let',
#   'us',
#   ',',
#   'then',
#   ',',
#   'with',
#   'courag',
#   'and',
#   'confid',
#   'pursu',
#   'our',
#   'own',
#   'feder',
#   'and',
#   'republican',
#   'principl',
#   ',',
#   'our',
#   'attach',
#   'to',
#   'union',
#   'and',
#   'repres',
#   'govern',
#   '.',
#   'kind',
#   'separ',
#   'by',
#   'natur',
#   'and',
#   'a',
#   'wide',
#   'ocean',
#   'from',
#   'the',
#   'extermin',
#   'havoc',
#   'of',
#   'one',
#   'quarter',
#   'of',
#   'the',
#   'globe',
#   ';',
#   'too',
#   'high-mind',
#   'to',
#   'endur',
#   'the',
#   'degrad',
#   'of',
#   'the',
#   'other',
#   ';',
#   'possess',
#   'a',
#   'chosen',
#   'countri',
#   ',',
#   'with',
#   'room',
#   'enough',
#   'for',
#   'our',
#   'descend',
#   'to',
#   'the',
#   'thousandth',
#   'and',
#   'thousandth',
#   'generat',
#   ';',
#   'entertain',
#   'a',
#   'due',
#   'sens',
#   'of',
#   'our',
#   'equal',
#   'right',
#   'to',
#   'the',
#   'use',
#   'of',
#   'our',
#   'own',
#   'faculti',
#   ',',
#   'to',
#   'the',
#   'acquisit',
#   'of',
#   'our',
#   'own',
#   'industri',
#   ',',
#   'to',
#   'honor',
#   'and',
#   'confid',
#   'from',
#   'our',
#   'fellow-citizen',
#   ',',
#   'result',
#   'not',
#   'from',
#   'birth',
#   ',',
#   'but',
#   'from',
#   'our',
#   'action',
#   'and',
#   'their',
#   'sens',
#   'of',
#   'them',
#   ';',
#   'enlighten',
#   'by',
#   'a',
#   'benign',
#   'religion',
#   ',',
#   'profess',
#   ',',
#   'inde',
#   ',',
#   'and',
#   'practic',
#   'in',
#   'various',
#   'form',
#   ',',
#   'yet',
#   'all',
#   'of',
#   'them',
#   'inculc',
#   'honesti',
#   ',',
#   ...],
#  ['march',
#   '4',
#   ',',
#   '1813',
#   'about',
#   'to',
#   'add',
#   'the',
#   'solemn',
#   'of',
#   'an',
#   'oath',
#   'to',
#   'the',
#   'oblig',
#   'impos',
#   'by',
#   'a',
#   'second',
#   'call',
#   'to',
#   'the',
#   'station',
#   'in',
#   'which',
#   'my',
#   'countri',
#   'heretofor',
#   'place',
#   'me',
#   ',',
#   'i',
#   'find',
#   'in',
#   'the',
#   'presenc',
#   'of',
#   'this',
#   'respect',
#   'assembl',
#   'an',
#   'opportun',
#   'of',
#   'public',
#   'repeat',
#   'my',
#   'profound',
#   'sens',
#   'of',
#   'so',
#   'distinguish',
#   'a',
#   'confid',
#   'and',
#   'of',
#   'the',
#   'respons',
#   'unit',
#   'with',
#   'it',
#   '.',
#   'the',
#   'impress',
#   'on',
#   'me',
#   'are',
#   'strengthen',
#   'by',
#   'such',
#   'an',
#   'evid',
#   'that',
#   'my',
#   'faith',
#   'endeavor',
#   'to',
#   'discharg',
#   'my',
#   'arduous',
#   'duti',
#   'have',
#   'been',
#   'favor',
#   'estim',
#   ',',
#   'and',
#   'by',
#   'a',
#   'consider',
#   'of',
#   'the',
#   'moment',
#   'period',
#   'at',
#   'which',
#   'the',
#   'trust',
#   'has',
#   'been',
#   'renew',
#   '.',
#   'from',
#   'the',
#   'weight',
#   'and',
#   'magnitud',
#   'now',
#   'belong',
#   'to',
#   'it',
#   'i',
#   'should',
#   'be',
#   'compel',
#   'to',
#   'shrink',
#   'if',
#   'i',
#   'had',
#   'less',
#   'relianc',
#   'on',
#   'the',
#   'support',
#   'of',
#   'an',
#   'enlighten',
#   'and',
#   'generous',
#   'peopl',
#   ',',
#   'and',
#   'felt',
#   'less',
#   'deepli',
#   'a',
#   'convict',
#   'that',
#   'the',
#   'war',
#   'with',
#   'a',
#   'power',
#   'nation',
#   ',',
#   'which',
#   'form',
#   'so',
#   'promin',
#   'a',
#   'featur',
#   'in',
#   'our',
#   'situat',
#   ',',
#   'is',
#   'stamp',
#   'with',
#   'that',
#   'justic',
#   'which',
#   'invit',
#   'the',
#   'smile',
#   'of',
#   'heaven',
#   'on',
#   'the',
#   'mean',
#   'of',
#   'conduct',
#   'it',
#   'to',
#   'a',
#   'success',
#   'termin',
#   '.',
#   'may',
#   'we',
#   'not',
#   'cherish',
#   'this',
#   'sentiment',
#   'without',
#   'presumpt',
#   'when',
#   'we',
#   'reflect',
#   'on',
#   'the',
#   'charact',
#   'by',
#   'which',
#   'this',
#   'war',
#   'is',
#   'distinguish',
#   '?',
#   'it',
#   'was',
#   'not',
#   'declar',
#   'on',
#   'the',
#   'part',
#   'of',
#   'the',
#   'unit',
#   'state',
#   'until',
#   'it',
#   'had',
#   'been',
#   'long',
#   'made',
#   'on',
#   'them',
#   ',',
#   'in',
#   'realiti',
#   'though',
#   'not',
#   'in',
#   'name',
#   ';',
#   'until',
#   'argument',
#   'and',
#   'postul',
#   'had',
#   'been',
#   'exhaust',
#   ';',
#   'until',
#   'a',
#   'posit',
#   'declar',
#   'had',
#   'been',
#   'receiv',
#   'that',
#   'the',
#   'wrong',
#   'provok',
#   'it',
#   'would',
#   'not',
#   'be',
#   'discontinu',
#   ';',
#   'nor',
#   'until',
#   'this',
#   'last',
#   'appeal',
#   'could',
#   'no',
#   'longer',
#   'be',
#   'delay',
#   'without',
#   'break',
#   'down',
#   'the',
#   'spirit',
#   'of',
#   'the',
#   'nation',
#   ',',
#   'destroy',
#   'all',
#   'confid',
#   'in',
#   'itself',
#   'and',
#   'in',
#   'it',
#   'polit',
#   'institut',
#   ',',
#   'and',
#   'either',
#   'perpetu',
#   'a',
#   'state',
#   'of',
#   'disgrac',
#   'suffer',
#   'or',
#   'regain',
#   'by',
#   'more',
#   'cost',
#   'sacrific',
#   'and',
#   'more',
#   'sever',
#   'struggl',
#   'our',
#   'lost',
#   'rank',
#   'and',
#   'respect',
#   'among',
#   'independ',
#   'power',
#   '.',
#   'on',
#   'the',
#   'issu',
#   'of',
#   'the',
#   'war',
#   'are',
#   'stake',
#   'our',
#   'nation',
#   'sovereignti',
#   'on',
#   'the',
#   'high',
#   'sea',
#   'and',
#   'the',
#   'secur',
#   'of',
#   'an',
#   'import',
#   'class',
#   'of',
#   'citizen',
#   ',',
#   'whose',
#   'occup',
#   'give',
#   'the',
#   'proper',
#   'valu',
#   'to',
#   'those',
#   'of',
#   'everi',
#   'other',
#   'class',
#   '.',
#   'not',
#   'to',
#   'contend',
#   'for',
#   'such',
#   'a',
#   'stake',
#   'is',
#   'to',
#   'surrend',
#   'our',
#   'equal',
#   'with',
#   'other',
#   'power',
#   'on',
#   'the',
#   'element',
#   'common',
#   'to',
#   'all',
#   'and',
#   'to',
#   'violat',
#   'the',
#   'sacr',
#   'titl',
#   'which',
#   'everi',
#   'member',
#   'of',
#   'the',
#   'societi',
#   'has',
#   'to',
#   'it',
#   'protect',
#   '.',
#   'i',
#   'need',
#   'not',
#   'call',
#   'into',
#   'view',
#   'the',
#   'unlaw',
#   'of',
#   'the',
#   'practic',
#   'by',
#   'which',
#   'our',
#   'marin',
#   'are',
#   'forc',
#   'at',
#   'the',
#   'will',
#   'of',
#   'everi',
#   'cruis',
#   'offic',
#   'from',
#   'their',
#   'own',
#   'vessel',
#   'into',
#   'foreign',
#   'one',
#   ',',
#   'nor',
#   'paint',
#   'the',
#   'outrag',
#   'insepar',
#   'from',
#   'it',
#   '.',
#   'the',
#   'proof',
#   'are',
#   'in',
#   'the',
#   'record',
#   'of',
#   'each',
#   'success',
#   'administr',
#   'of',
#   'our',
#   'govern',
#   ',',
#   'and',
#   'the',
#   'cruel',
#   'suffer',
#   'of',
#   'that',
#   'portion',
#   'of',
#   'the',
#   'american',
#   'peopl',
#   'have',
#   'found',
#   'their',
#   'way',
#   'to',
#   'everi',
#   'bosom',
#   'not',
#   'dead',
#   'to',
#   'the',
#   'sympathi',
#   'of',
#   'human',
#   'natur',
#   '.',
#   'as',
#   'the',
#   'war',
#   'was',
#   'just',
#   'in',
#   'it',
#   'origin',
#   'and',
#   'necessari',
#   'and',
#   'nobl',
#   'in',
#   'it',
#   'object',
#   ',',
#   'we',
#   'can',
#   'reflect',
#   'with',
#   'a',
#   'proud',
#   'satisfact',
#   'that',
#   'in',
#   'carri',
#   'it',
#   'on',
#   'no',
#   'principl',
#   'of',
#   'justic',
#   'or',
#   'honor',
#   ',',
#   'no',
#   'usag',
#   'of',
#   'civil',
#   'nation',
#   ',',
#   'no',
#   'precept',
#   'of',
#   'courtesi',
#   'or',
#   'human',
#   ',',
#   'have',
#   'been',
#   'infring',
#   '.',
#   'the',
#   'war',
#   'has',
#   'been',
#   'wage',
#   'on',
#   'our',
#   'part',
#   'with',
#   'scrupul',
#   'regard',
#   'to',
#   'all',
#   'these',
#   'oblig',
#   ',',
#   'and',
#   'in',
#   'a',
#   'spirit',
#   'of',
#   'liber',
#   'which',
#   'was',
#   'never',
#   'surpass',
#   '.',
#   'how',
#   'littl',
#   'has',
#   'been',
#   'the',
#   'effect',
#   'of',
#   'this',
#   'exampl',
#   'on',
#   'the',
#   'conduct',
#   'of',
#   'the',
#   'enemi',
#   '!',
#   'they',
#   'have',
#   'retain',
#   'as',
#   'prison',
#   'of',
#   'war',
#   'citizen',
#   'of',
#   'the',
#   'unit',
#   'state',
#   'not',
#   'liabl',
#   'to',
#   'be',
#   'so',
#   'consid',
#   'under',
#   'the',
#   'usag',
#   'of',
#   'war',
#   '.',
#   'they',
#   'have',
#   'refus',
#   'to',
#   'consid',
#   'as',
#   'prison',
#   'of',
#   'war',
#   ',',
#   'and',
#   'threaten',
#   'to',
#   'punish',
#   'as',
#   'traitor',
#   'and',
#   'desert',
#   ',',
#   'person',
#   'emigr',
#   'without',
#   'restraint',
#   'to',
#   'the',
#   'unit',
#   'state',
#   ',',
#   'incorpor',
#   'by',
#   'natur',
#   'into',
#   'our',
#   'polit',
#   'famili',
#   ',',
#   'and',
#   'fight',
#   'under',
#   'the',
#   'author',
#   'of',
#   'their',
#   'adopt',
#   'countri',
#   'in',
#   'open',
#   'and',
#   'honor',
#   'war',
#   'for',
#   'the',
#   'mainten',
#   'of',
#   'it',
#   'right',
#   'and',
#   'safeti',
#   '.',
#   'such',
#   'is',
#   'the',
#   'avow',
#   'purpos',
#   'of',
#   'a',
#   'govern',
#   'which',
#   'is',
#   'in',
#   'the',
#   'practic',
#   'of',
#   'natur',
#   'by',
#   'thousand',
#   'citizen',
#   'of',
#   'other',
#   'countri',
#   ',',
#   'and',
#   'not',
#   'onli',
#   'of',
#   'permit',
#   'but',
#   'compel',
#   'them',
#   'to',
#   'fight',
#   'it',
#   'battl',
#   'against',
#   'their',
#   'nativ',
#   'countri',
#   '.',
#   'they',
#   'have',
#   'not',
#   ',',
#   'it',
#   'is',
#   'true',
#   ',',
#   'taken',
#   'into',
#   'their',
#   'own',
#   'hand',
#   'the',
#   'hatchet',
#   'and',
#   'the',
#   'knife',
#   ',',
#   'devot',
#   'to',
#   'indiscrimin',
#   'massacr',
#   ',',
#   'but',
#   'they',
#   'have',
#   'let',
#   'loos',
#   'the',
#   'savag',
#   'arm',
#   'with',
#   'these',
#   'cruel',
#   'instrument',
#   ';',
#   'have',
#   'allur',
#   'them',
#   'into',
#   'their',
#   'servic',
#   ',',
#   'and',
#   'carri',
#   'them',
#   'to',
#   'battl',
#   'by',
#   'their',
#   'side',
#   ',',
#   'eager',
#   'to',
#   'glut',
#   'their',
#   'savag',
#   'thirst',
#   'with',
#   'the',
#   'blood',
#   'of',
#   'the',
#   'vanquish',
#   'and',
#   'to',
#   'finish',
#   'the',
#   'work',
#   'of',
#   'tortur',
#   'and',
#   'death',
#   'on',
#   'maim',
#   'and',
#   'defenseless',
#   'captiv',
#   '.',
#   'and',
#   ',',
#   'what',
#   'was',
#   'never',
#   'befor',
#   'seen',
#   ',',
#   'british',
#   'command',
#   'have',
#   'extort',
#   'victori',
#   'over',
#   'the',
#   'unconquer',
#   'valor',
#   'of',
#   'our',
#   'troop',
#   'by',
#   'present',
#   'to',
#   'the',
#   'sympathi',
#   'of',
#   'their',
#   'chief',
#   'captiv',
#   'await',
#   'massacr',
#   'from',
#   'their',
#   'savag',
#   'associ',
#   '.',
#   'and',
#   'now',
#   'we',
#   'find',
#   'them',
#   ',',
#   'in',
#   'further',
#   'contempt',
#   'of',
#   'the',
#   'mode',
#   'of',
#   'honor',
#   'warfar',
#   ',',
#   'suppli',
#   'the',
#   'place',
#   'of',
#   'a',
#   'conquer',
#   'forc',
#   'by',
#   'attempt',
#   'to',
#   'disorgan',
#   'our',
#   'polit',
#   'societi',
#   ',',
#   'to',
#   'dismemb',
#   'our',
#   'confeder',
#   'republ',
#   '.',
#   'happili',
#   ',',
#   'like',
#   'other',
#   ',',
#   'these',
#   'will',
#   'recoil',
#   'on',
#   'the',
#   'author',
#   ';',
#   'but',
#   'they',
#   'mark',
#   'the',
#   'degener',
#   'counsel',
#   'from',
#   'which',
#   'they',
#   'eman',
#   ',',
#   'and',
#   'if',
#   'they',
#   'did',
#   'not',
#   'belong',
#   'to',
#   'a',
#   'sens',
#   'of',
#   'unexampl',
#   'inconsist',
#   'might',
#   'excit',
#   'the',
#   'greater',
#   'wonder',
#   'as',
#   'proceed',
#   'from',
#   'a',
#   'govern',
#   'which',
#   'found',
#   'the',
#   'veri',
#   'war',
#   'in',
#   'which',
#   'it',
#   'has',
#   'been',
#   'so',
#   'long',
#   'engag',
#   'on',
#   'a',
#   'charg',
#   'against',
#   'the',
#   'disorgan',
#   'and',
#   'insurrect',
#   'polici',
#   'of',
#   'it',
#   'adversari',
#   '.',
#   'to',
#   'render',
#   'the',
#   'justic',
#   'of',
#   'the',
#   'war',
#   'on',
#   'our',
#   'part',
#   'the',
#   'more',
#   'conspicu',
#   ',',
#   'the',
#   'reluct',
#   'to',
#   'commenc',
#   'it',
#   'was',
#   'follow',
#   'by',
#   'the',
#   'earliest',
#   'and',
#   'strongest',
#   'manifest',
#   'of',
#   'a',
#   'disposit',
#   'to',
#   'arrest',
#   'it',
#   'progress',
#   '.',
#   'the',
#   'sword',
#   'was',
#   'scarc',
#   'out',
#   'of',
#   'the',
#   'scabbard',
#   'befor',
#   'the',
#   'enemi',
#   'was',
#   'appris',
#   'of',
#   'the',
#   'reason',
#   'term',
#   'on',
#   'which',
#   'it',
#   'would',
#   'be',
#   'resheath',
#   '.',
#   'still',
#   'more',
#   'precis',
#   'advanc',
#   'were',
#   'repeat',
#   ',',
#   'and',
#   'have',
#   'been',
#   'receiv',
#   'in',
#   'a',
#   'spirit',
#   'forbid',
#   'everi',
#   'relianc',
#   'not',
#   'place',
#   'on',
#   'the',
#   'militari',
#   'resourc',
#   'of',
#   'the',
#   'nation',
#   '.',
#   'these',
#   'resourc',
#   'are',
#   'ampli',
#   'suffici',
#   'to',
#   'bring',
#   'the',
#   'war',
#   ...],
#  ['i',
#   'should',
#   'be',
#   'destitut',
#   'of',
#   'feel',
#   'if',
#   'i',
#   'was',
#   'not',
#   'deepli',
#   'affect',
#   'by',
#   'the',
#   'strong',
#   'proof',
#   'which',
#   'my',
#   'fellow-citizen',
#   'have',
#   'given',
#   'me',
#   'of',
#   'their',
#   'confid',
#   'in',
#   'call',
#   'me',
#   'to',
#   'the',
#   'high',
#   'offic',
#   'whose',
#   'function',
#   'i',
#   'am',
#   'about',
#   'to',
#   'assum',
#   '.',
#   'as',
#   'the',
#   'express',
#   'of',
#   'their',
#   'good',
#   'opinion',
#   'of',
#   'my',
#   'conduct',
#   'in',
#   'the',
#   'public',
#   'servic',
#   ',',
#   'i',
#   'deriv',
#   'from',
#   'it',
#   'a',
#   'gratif',
#   'which',
#   'those',
#   'who',
#   'are',
#   'conscious',
#   'of',
#   'have',
#   'done',
#   'all',
#   'that',
#   'they',
#   'could',
#   'to',
#   'merit',
#   'it',
#   'can',
#   'alon',
#   'feel',
#   '.',
#   'my',
#   'sensibl',
#   'is',
#   'increas',
#   'by',
#   'a',
#   'just',
#   'estim',
#   'of',
#   'the',
#   'import',
#   'of',
#   'the',
#   'trust',
#   'and',
#   'of',
#   'the',
#   'natur',
#   'and',
#   'extent',
#   'of',
#   'it',
#   'duti',
#   ',',
#   'with',
#   'the',
#   'proper',
#   'discharg',
#   'of',
#   'which',
#   'the',
#   'highest',
#   'interest',
#   'of',
#   'a',
#   'great',
#   'and',
#   'free',
#   'peopl',
#   'are',
#   'intim',
#   'connect',
#   '.',
#   'conscious',
#   'of',
#   'my',
#   'own',
#   'defici',
#   ',',
#   'i',
#   'can',
#   'not',
#   'enter',
#   'on',
#   'these',
#   'duti',
#   'without',
#   'great',
#   'anxieti',
#   'for',
#   'the',
#   'result',
#   '.',
#   'from',
#   'a',
#   'just',
#   'respons',
#   'i',
#   'will',
#   'never',
#   'shrink',
#   ',',
#   'calcul',
#   'with',
#   'confid',
#   'that',
#   'in',
#   'my',
#   'best',
#   'effort',
#   'to',
#   'promot',
#   'the',
#   'public',
#   'welfar',
#   'my',
#   'motiv',
#   'will',
#   'alway',
#   'be',
#   'duli',
#   'appreci',
#   'and',
#   'my',
#   'conduct',
#   'be',
#   'view',
#   'with',
#   'that',
#   'candor',
#   'and',
#   'indulg',
#   'which',
#   'i',
#   'have',
#   'experienc',
#   'in',
#   'other',
#   'station',
#   '.',
#   'in',
#   'commenc',
#   'the',
#   'duti',
#   'of',
#   'the',
#   'chief',
#   'execut',
#   'offic',
#   'it',
#   'has',
#   'been',
#   'the',
#   'practic',
#   'of',
#   'the',
#   'distinguish',
#   'men',
#   'who',
#   'have',
#   'gone',
#   'befor',
#   'me',
#   'to',
#   'explain',
#   'the',
#   'principl',
#   'which',
#   'would',
#   'govern',
#   'them',
#   'in',
#   'their',
#   'respect',
#   'administr',
#   '.',
#   'in',
#   'follow',
#   'their',
#   'vener',
#   'exampl',
#   'my',
#   'attent',
#   'is',
#   'natur',
#   'drawn',
#   'to',
#   'the',
#   'great',
#   'caus',
#   'which',
#   'have',
#   'contribut',
#   'in',
#   'a',
#   'princip',
#   'degre',
#   'to',
#   'produc',
#   'the',
#   'present',
#   'happi',
#   'condit',
#   'of',
#   'the',
#   'unit',
#   'state',
#   '.',
#   'they',
#   'will',
#   'best',
#   'explain',
#   'the',
#   'natur',
#   'of',
#   'our',
#   'duti',
#   'and',
#   'shed',
#   'much',
#   'light',
#   'on',
#   'the',
#   'polici',
#   'which',
#   'ought',
#   'to',
#   'be',
#   'pursu',
#   'in',
#   'futur',
#   '.',
#   'from',
#   'the',
#   'commenc',
#   'of',
#   'our',
#   'revolut',
#   'to',
#   'the',
#   'present',
#   'day',
#   'almost',
#   'forti',
#   'year',
#   'have',
#   'elaps',
#   ',',
#   'and',
#   'from',
#   'the',
#   'establish',
#   'of',
#   'this',
#   'constitut',
#   'twenty-eight',
#   '.',
#   'through',
#   'this',
#   'whole',
#   'term',
#   'the',
#   'govern',
#   'has',
#   'been',
#   'what',
#   'may',
#   'emphat',
#   'be',
#   'call',
#   'self-govern',
#   '.',
#   'and',
#   'what',
#   'has',
#   'been',
#   'the',
#   'effect',
#   '?',
#   'to',
#   'whatev',
#   'object',
#   'we',
#   'turn',
#   'our',
#   'attent',
#   ',',
#   'whether',
#   'it',
#   'relat',
#   'to',
#   'our',
#   'foreign',
#   'or',
#   'domest',
#   'concern',
#   ',',
#   'we',
#   'find',
#   'abund',
#   'caus',
#   'to',
#   'felicit',
#   'ourselv',
#   'in',
#   'the',
#   'excel',
#   'of',
#   'our',
#   'institut',
#   '.',
#   'dure',
#   'a',
#   'period',
#   'fraught',
#   'with',
#   'difficulti',
#   'and',
#   'mark',
#   'by',
#   'veri',
#   'extraordinari',
#   'event',
#   'the',
#   'unit',
#   'state',
#   'have',
#   'flourish',
#   'beyond',
#   'exampl',
#   '.',
#   'their',
#   'citizen',
#   'individu',
#   'have',
#   'been',
#   'happi',
#   'and',
#   'the',
#   'nation',
#   'prosper',
#   '.',
#   'under',
#   'this',
#   'constitut',
#   'our',
#   'commerc',
#   'has',
#   'been',
#   'wise',
#   'regul',
#   'with',
#   'foreign',
#   'nation',
#   'and',
#   'between',
#   'the',
#   'state',
#   ';',
#   'new',
#   'state',
#   'have',
#   'been',
#   'admit',
#   'into',
#   'our',
#   'union',
#   ';',
#   'our',
#   'territori',
#   'has',
#   'been',
#   'enlarg',
#   'by',
#   'fair',
#   'and',
#   'honor',
#   'treati',
#   ',',
#   'and',
#   'with',
#   'great',
#   'advantag',
#   'to',
#   'the',
#   'origin',
#   'state',
#   ';',
#   'the',
#   'state',
#   ',',
#   'respect',
#   'protect',
#   'by',
#   'the',
#   'nation',
#   'govern',
#   'under',
#   'a',
#   'mild',
#   ',',
#   'parent',
#   'system',
#   'against',
#   'foreign',
#   'danger',
#   ',',
#   'and',
#   'enjoy',
#   'within',
#   'their',
#   'separ',
#   'sphere',
#   ',',
#   'by',
#   'a',
#   'wise',
#   'partit',
#   'of',
#   'power',
#   ',',
#   'a',
#   'just',
#   'proport',
#   'of',
#   'the',
#   'sovereignti',
#   ',',
#   'have',
#   'improv',
#   'their',
#   'polic',
#   ',',
#   'extend',
#   'their',
#   'settlement',
#   ',',
#   'and',
#   'attain',
#   'a',
#   'strength',
#   'and',
#   'matur',
#   'which',
#   'are',
#   'the',
#   'best',
#   'proof',
#   'of',
#   'wholesom',
#   'law',
#   'well',
#   'administ',
#   '.',
#   'and',
#   'if',
#   'we',
#   'look',
#   'to',
#   'the',
#   'condit',
#   'of',
#   'individu',
#   'what',
#   'a',
#   'proud',
#   'spectacl',
#   'doe',
#   'it',
#   'exhibit',
#   '!',
#   'on',
#   'whom',
#   'has',
#   'oppress',
#   'fallen',
#   'in',
#   'ani',
#   'quarter',
#   'of',
#   'our',
#   'union',
#   '?',
#   'who',
#   'has',
#   'been',
#   'depriv',
#   'of',
#   'ani',
#   'right',
#   'of',
#   'person',
#   'or',
#   'properti',
#   '?',
#   'who',
#   'restrain',
#   'from',
#   'offer',
#   'his',
#   'vow',
#   'in',
#   'the',
#   'mode',
#   'which',
#   'he',
#   'prefer',
#   'to',
#   'the',
#   'divin',
#   'author',
#   'of',
#   'his',
#   'be',
#   '?',
#   'it',
#   'is',
#   'well',
#   'known',
#   'that',
#   'all',
#   'these',
#   'bless',
#   'have',
#   'been',
#   'enjoy',
#   'in',
#   'their',
#   'fullest',
#   'extent',
#   ';',
#   'and',
#   'i',
#   'add',
#   'with',
#   'peculiar',
#   'satisfact',
#   'that',
#   'there',
#   'has',
#   'been',
#   'no',
#   'exampl',
#   'of',
#   'a',
#   'capit',
#   'punish',
#   'be',
#   'inflict',
#   'on',
#   'anyon',
#   'for',
#   'the',
#   'crime',
#   'of',
#   'high',
#   'treason',
#   '.',
#   'some',
#   'who',
#   'might',
#   'admit',
#   'the',
#   'compet',
#   'of',
#   'our',
#   'govern',
#   'to',
#   'these',
#   'benefic',
#   'duti',
#   'might',
#   'doubt',
#   'it',
#   'in',
#   'trial',
#   'which',
#   'put',
#   'to',
#   'the',
#   'test',
#   'it',
#   'strength',
#   'and',
#   'effici',
#   'as',
#   'a',
#   'member',
#   'of',
#   'the',
#   'great',
#   'communiti',
#   'of',
#   'nation',
#   '.',
#   'here',
#   'too',
#   'experi',
#   'has',
#   'afford',
#   'us',
#   'the',
#   'most',
#   'satisfactori',
#   'proof',
#   'in',
#   'it',
#   'favor',
#   '.',
#   'just',
#   'as',
#   'this',
#   'constitut',
#   'was',
#   'put',
#   'into',
#   'action',
#   'sever',
#   'of',
#   'the',
#   'princip',
#   'state',
#   'of',
#   'europ',
#   'had',
#   'becom',
#   'much',
#   'agit',
#   'and',
#   'some',
#   'of',
#   'them',
#   'serious',
#   'convuls',
#   '.',
#   'destruct',
#   'war',
#   'ensu',
#   ',',
#   'which',
#   'have',
#   'of',
#   'late',
#   'onli',
#   'been',
#   'termin',
#   '.',
#   'in',
#   'the',
#   'cours',
#   'of',
#   'these',
#   'conflict',
#   'the',
#   'unit',
#   'state',
#   'receiv',
#   'great',
#   'injuri',
#   'from',
#   'sever',
#   'of',
#   'the',
#   'parti',
#   '.',
#   'it',
#   'was',
#   'their',
#   'interest',
#   'to',
#   'stand',
#   'aloof',
#   'from',
#   'the',
#   'contest',
#   ',',
#   'to',
#   'demand',
#   'justic',
#   'from',
#   'the',
#   'parti',
#   'commit',
#   'the',
#   'injuri',
#   ',',
#   'and',
#   'to',
#   'cultiv',
#   'by',
#   'a',
#   'fair',
#   'and',
#   'honor',
#   'conduct',
#   'the',
#   'friendship',
#   'of',
#   'all',
#   '.',
#   'war',
#   'becam',
#   'at',
#   'length',
#   'inevit',
#   ',',
#   'and',
#   'the',
#   'result',
#   'has',
#   'shown',
#   'that',
#   'our',
#   'govern',
#   'is',
#   'equal',
#   'to',
#   'that',
#   ',',
#   'the',
#   'greatest',
#   'of',
#   'trial',
#   ',',
#   'under',
#   'the',
#   'most',
#   'unfavor',
#   'circumst',
#   '.',
#   'of',
#   'the',
#   'virtu',
#   'of',
#   'the',
#   'peopl',
#   'and',
#   'of',
#   'the',
#   'heroic',
#   'exploit',
#   'of',
#   'the',
#   'armi',
#   ',',
#   'the',
#   'navi',
#   ',',
#   'and',
#   'the',
#   'militia',
#   'i',
#   'need',
#   'not',
#   'speak',
#   '.',
#   'such',
#   ',',
#   'then',
#   ',',
#   'is',
#   'the',
#   'happi',
#   'govern',
#   'under',
#   'which',
#   'we',
#   'live',
#   '--',
#   'a',
#   'govern',
#   'adequ',
#   'to',
#   'everi',
#   'purpos',
#   'for',
#   'which',
#   'the',
#   'social',
#   'compact',
#   'is',
#   'form',
#   ';',
#   'a',
#   'govern',
#   'elect',
#   'in',
#   'all',
#   'it',
#   'branch',
#   ',',
#   'under',
#   'which',
#   'everi',
#   'citizen',
#   'may',
#   'by',
#   'his',
#   'merit',
#   'obtain',
#   'the',
#   'highest',
#   'trust',
#   'recogn',
#   'by',
#   'the',
#   'constitut',
#   ';',
#   'which',
#   'contain',
#   'within',
#   'it',
#   'no',
#   'caus',
#   'of',
#   'discord',
#   ',',
#   'none',
#   'to',
#   'put',
#   'at',
#   'varianc',
#   'one',
#   'portion',
#   'of',
#   'the',
#   'communiti',
#   'with',
#   'anoth',
#   ';',
#   'a',
#   'govern',
#   'which',
#   'protect',
#   'everi',
#   'citizen',
#   'in',
#   'the',
#   'full',
#   'enjoy',
#   'of',
#   'his',
#   'right',
#   ',',
#   'and',
#   'is',
#   'abl',
#   'to',
#   'protect',
#   'the',
#   'nation',
#   'against',
#   'injustic',
#   'from',
#   'foreign',
#   'power',
#   '.',
#   'other',
#   'consider',
#   'of',
#   'the',
#   'highest',
#   'import',
#   'admonish',
#   'us',
#   'to',
#   'cherish',
#   'our',
#   'union',
#   'and',
#   'to',
#   'cling',
#   'to',
#   'the',
#   'govern',
#   'which',
#   'support',
#   'it',
#   '.',
#   'fortun',
#   'as',
#   'we',
#   'are',
#   'in',
#   'our',
#   'polit',
#   'institut',
#   ',',
#   'we',
#   'have',
#   'not',
#   'been',
#   'less',
#   'so',
#   'in',
#   'other',
#   'circumst',
#   'on',
#   'which',
#   'our',
#   'prosper',
#   'and',
#   'happi',
#   'essenti',
#   'depend',
#   '.',
#   'situat',
#   'within',
#   'the',
#   'temper',
#   'zone',
#   ',',
#   'and',
#   'extend',
#   'through',
#   'mani',
#   'degre',
#   'of',
#   'latitud',
#   'along',
#   'the',
#   'atlant',
#   ',',
#   'the',
#   'unit',
#   'state',
#   'enjoy',
#   'all',
#   'the',
#   'varieti',
#   'of',
#   'climat',
#   ',',
#   'and',
#   'everi',
#   'product',
#   'incid',
#   'to',
#   'that',
#   'portion',
#   'of',
#   'the',
#   'globe',
#   '.',
#   'penetr',
#   'intern',
#   'to',
#   'the',
#   'great',
#   'lake',
#   ...],
#  ['in',
#   'complianc',
#   'with',
#   'an',
#   'usag',
#   'coeval',
#   'with',
#   'the',
#   'exist',
#   'of',
#   'our',
#   'feder',
#   'constitut',
#   ',',
#   'and',
#   'sanction',
#   'by',
#   'the',
#   'exampl',
#   'of',
#   'my',
#   'predecessor',
#   'in',
#   'the',
#   'career',
#   'upon',
#   'which',
#   'i',
#   'am',
#   'about',
#   'to',
#   'enter',
#   ',',
#   'i',
#   'appear',
#   ',',
#   'my',
#   'fellow-citizen',
#   ',',
#   'in',
#   'your',
#   'presenc',
#   'and',
#   'in',
#   'that',
#   'of',
#   'heaven',
#   'to',
#   'bind',
#   'myself',
#   'by',
#   'the',
#   'solemn',
#   'of',
#   'religi',
#   'oblig',
#   'to',
#   'the',
#   'faith',
#   'perform',
#   'of',
#   'the',
#   'duti',
#   'allot',
#   'to',
#   'me',
#   'in',
#   'the',
#   'station',
#   'to',
#   'which',
#   'i',
#   'have',
#   'been',
#   'call',
#   '.',
#   'in',
#   'unfold',
#   'to',
#   'my',
#   'countrymen',
#   'the',
#   'principl',
#   'by',
#   'which',
#   'i',
#   'shall',
#   'be',
#   'govern',
#   'in',
#   'the',
#   'fulfil',
#   'of',
#   'those',
#   'duti',
#   'my',
#   'first',
#   'resort',
#   'will',
#   'be',
#   'to',
#   'that',
#   'constitut',
#   'which',
#   'i',
#   'shall',
#   'swear',
#   'to',
#   'the',
#   'best',
#   'of',
#   'my',
#   'abil',
#   'to',
#   'preserv',
#   ',',
#   'protect',
#   ',',
#   'and',
#   'defend',
#   '.',
#   'that',
#   'rever',
#   'instrument',
#   'enumer',
#   'the',
#   'power',
#   'and',
#   'prescrib',
#   'the',
#   'duti',
#   'of',
#   'the',
#   'execut',
#   'magistr',
#   ',',
#   'and',
#   'in',
#   'it',
#   'first',
#   'word',
#   'declar',
#   'the',
#   'purpos',
#   'to',
#   'which',
#   'these',
#   'and',
#   'the',
#   'whole',
#   'action',
#   'of',
#   'the',
#   'govern',
#   'institut',
#   'by',
#   'it',
#   'should',
#   'be',
#   'invari',
#   'and',
#   'sacr',
#   'devot',
#   '--',
#   'to',
#   'form',
#   'a',
#   'more',
#   'perfect',
#   'union',
#   ',',
#   'establish',
#   'justic',
#   ',',
#   'insur',
#   'domest',
#   'tranquil',
#   ',',
#   'provid',
#   'for',
#   'the',
#   'common',
#   'defens',
#   ',',
#   'promot',
#   'the',
#   'general',
#   'welfar',
#   ',',
#   'and',
#   'secur',
#   'the',
#   'bless',
#   'of',
#   'liberti',
#   'to',
#   'the',
#   'peopl',
#   'of',
#   'this',
#   'union',
#   'in',
#   'their',
#   'success',
#   'generat',
#   '.',
#   'sinc',
#   'the',
#   'adopt',
#   'of',
#   'this',
#   'social',
#   'compact',
#   'one',
#   'of',
#   'these',
#   'generat',
#   'has',
#   'pass',
#   'away',
#   '.',
#   'it',
#   'is',
#   'the',
#   'work',
#   'of',
#   'our',
#   'forefath',
#   '.',
#   'administ',
#   'by',
#   'some',
#   'of',
#   'the',
#   'most',
#   'emin',
#   'men',
#   'who',
#   'contribut',
#   'to',
#   'it',
#   'format',
#   ',',
#   'through',
#   'a',
#   'most',
#   'event',
#   'period',
#   'in',
#   'the',
#   'annal',
#   'of',
#   'the',
#   'world',
#   ',',
#   'and',
#   'through',
#   'all',
#   'the',
#   'vicissitud',
#   'of',
#   'peac',
#   'and',
#   'war',
#   'incident',
#   'to',
#   'the',
#   'condit',
#   'of',
#   'associ',
#   'man',
#   ',',
#   'it',
#   'has',
#   'not',
#   'disappoint',
#   'the',
#   'hope',
#   'and',
#   'aspir',
#   'of',
#   'those',
#   'illustri',
#   'benefactor',
#   'of',
#   'their',
#   'age',
#   'and',
#   'nation',
#   '.',
#   'it',
#   'has',
#   'promot',
#   'the',
#   'last',
#   'welfar',
#   'of',
#   'that',
#   'countri',
#   'so',
#   'dear',
#   'to',
#   'us',
#   'all',
#   ';',
#   'it',
#   'has',
#   'to',
#   'an',
#   'extent',
#   'far',
#   'beyond',
#   'the',
#   'ordinari',
#   'lot',
#   'of',
#   'human',
#   'secur',
#   'the',
#   'freedom',
#   'and',
#   'happi',
#   'of',
#   'this',
#   'peopl',
#   '.',
#   'we',
#   'now',
#   'receiv',
#   'it',
#   'as',
#   'a',
#   'precious',
#   'inherit',
#   'from',
#   'those',
#   'to',
#   'whom',
#   'we',
#   'are',
#   'indebt',
#   'for',
#   'it',
#   'establish',
#   ',',
#   'doubli',
#   'bound',
#   'by',
#   'the',
#   'exampl',
#   'which',
#   'they',
#   'have',
#   'left',
#   'us',
#   'and',
#   'by',
#   'the',
#   'bless',
#   'which',
#   'we',
#   'have',
#   'enjoy',
#   'as',
#   'the',
#   'fruit',
#   'of',
#   'their',
#   'labor',
#   'to',
#   'transmit',
#   'the',
#   'same',
#   'unimpair',
#   'to',
#   'the',
#   'succeed',
#   'generat',
#   '.',
#   'in',
#   'the',
#   'compass',
#   'of',
#   'thirty-six',
#   'year',
#   'sinc',
#   'this',
#   'great',
#   'nation',
#   'coven',
#   'was',
#   'institut',
#   'a',
#   'bodi',
#   'of',
#   'law',
#   'enact',
#   'under',
#   'it',
#   'author',
#   'and',
#   'in',
#   'conform',
#   'with',
#   'it',
#   'provis',
#   'has',
#   'unfold',
#   'it',
#   'power',
#   'and',
#   'carri',
#   'into',
#   'practic',
#   'oper',
#   'it',
#   'effect',
#   'energi',
#   '.',
#   'subordin',
#   'depart',
#   'have',
#   'distribut',
#   'the',
#   'execut',
#   'function',
#   'in',
#   'their',
#   'various',
#   'relat',
#   'to',
#   'foreign',
#   'affair',
#   ',',
#   'to',
#   'the',
#   'revenu',
#   'and',
#   'expenditur',
#   ',',
#   'and',
#   'to',
#   'the',
#   'militari',
#   'forc',
#   'of',
#   'the',
#   'union',
#   'by',
#   'land',
#   'and',
#   'sea',
#   '.',
#   'a',
#   'coordin',
#   'depart',
#   'of',
#   'the',
#   'judiciari',
#   'has',
#   'expound',
#   'the',
#   'constitut',
#   'and',
#   'the',
#   'law',
#   ',',
#   'settl',
#   'in',
#   'harmoni',
#   'coincid',
#   'with',
#   'the',
#   'legisl',
#   'will',
#   'numer',
#   'weighti',
#   'question',
#   'of',
#   'construct',
#   'which',
#   'the',
#   'imperfect',
#   'of',
#   'human',
#   'languag',
#   'had',
#   'render',
#   'unavoid',
#   '.',
#   'the',
#   'year',
#   'of',
#   'jubile',
#   'sinc',
#   'the',
#   'first',
#   'format',
#   'of',
#   'our',
#   'union',
#   'has',
#   'just',
#   'elaps',
#   'that',
#   'of',
#   'the',
#   'declar',
#   'of',
#   'our',
#   'independ',
#   'is',
#   'at',
#   'hand',
#   '.',
#   'the',
#   'consumm',
#   'of',
#   'both',
#   'was',
#   'effect',
#   'by',
#   'this',
#   'constitut',
#   '.',
#   'sinc',
#   'that',
#   'period',
#   'a',
#   'popul',
#   'of',
#   'four',
#   'million',
#   'has',
#   'multipli',
#   'to',
#   'twelv',
#   '.',
#   'a',
#   'territori',
#   'bound',
#   'by',
#   'the',
#   'mississippi',
#   'has',
#   'been',
#   'extend',
#   'from',
#   'sea',
#   'to',
#   'sea',
#   '.',
#   'new',
#   'state',
#   'have',
#   'been',
#   'admit',
#   'to',
#   'the',
#   'union',
#   'in',
#   'number',
#   'near',
#   'equal',
#   'to',
#   'those',
#   'of',
#   'the',
#   'first',
#   'confeder',
#   '.',
#   'treati',
#   'of',
#   'peac',
#   ',',
#   'amiti',
#   ',',
#   'and',
#   'commerc',
#   'have',
#   'been',
#   'conclud',
#   'with',
#   'the',
#   'princip',
#   'dominion',
#   'of',
#   'the',
#   'earth',
#   '.',
#   'the',
#   'peopl',
#   'of',
#   'other',
#   'nation',
#   ',',
#   'inhabit',
#   'of',
#   'region',
#   'acquir',
#   'not',
#   'by',
#   'conquest',
#   ',',
#   'but',
#   'by',
#   'compact',
#   ',',
#   'have',
#   'been',
#   'unit',
#   'with',
#   'us',
#   'in',
#   'the',
#   'particip',
#   'of',
#   'our',
#   'right',
#   'and',
#   'duti',
#   ',',
#   'of',
#   'our',
#   'burden',
#   'and',
#   'bless',
#   '.',
#   'the',
#   'forest',
#   'has',
#   'fallen',
#   'by',
#   'the',
#   'ax',
#   'of',
#   'our',
#   'woodsmen',
#   ';',
#   'the',
#   'soil',
#   'has',
#   'been',
#   'made',
#   'to',
#   'teem',
#   'by',
#   'the',
#   'tillag',
#   'of',
#   'our',
#   'farmer',
#   ';',
#   'our',
#   'commerc',
#   'has',
#   'whiten',
#   'everi',
#   'ocean',
#   '.',
#   'the',
#   'dominion',
#   'of',
#   'man',
#   'over',
#   'physic',
#   'natur',
#   'has',
#   'been',
#   'extend',
#   'by',
#   'the',
#   'invent',
#   'of',
#   'our',
# ...
#   'we',
#   'have',
#   'chosen',
#   'hope',
#   'over',
#   'fear',
#   ',',
#   'uniti',
#   'of',
#   'purpos',
#   'over',
#   'conflict',
#   'and',
#   'discord',
#   '.',
#   'on',
#   'this',
#   'day',
#   ',',
#   'we',
#   'come',
#   'to',
#   'proclaim',
#   'an',
#   'end',
#   'to',
#   'the',
#   'petti',
#   'grievanc',
#   'and',
#   'fals',
#   'promis',
#   ',',
#   'the',
#   'recrimin',
#   'and',
#   'worn',
#   'out',
#   'dogma',
#   ',',
#   'that',
#   'for',
#   'far',
#   'too',
#   'long',
#   'have',
#   'strangl',
#   'our',
#   'polit',
#   '.',
#   'we',
#   'remain',
#   'a',
#   'young',
#   'nation',
#   ',',
#   'but',
#   'in',
#   'the',
#   'word',
#   'of',
#   'scriptur',
#   ',',
#   'the',
#   'time',
#   'has',
#   'come',
#   'to',
#   'set',
#   'asid',
#   'childish',
#   'thing',
#   '.',
#   'the',
#   'time',
#   'has',
#   'come',
#   'to',
#   'reaffirm',
#   'our',
#   'endur',
#   'spirit',
#   ';',
#   'to',
#   'choos',
#   'our',
#   'better',
#   'histori',
#   ';',
#   'to',
#   'carri',
#   'forward',
#   'that',
#   'precious',
#   'gift',
#   ',',
#   'that',
#   'nobl',
#   'idea',
#   ',',
#   'pass',
#   'on',
#   'from',
#   'generat',
#   'to',
#   'generat',
#   ':',
#   'the',
#   'god-given',
#   'promis',
#   'that',
#   'all',
#   'are',
#   'equal',
#   ',',
#   'all',
#   'are',
#   'free',
#   ',',
#   'and',
#   'all',
#   'deserv',
#   'a',
#   'chanc',
#   'to',
#   'pursu',
#   'their',
#   'full',
#   'measur',
#   'of',
#   'happi',
#   '.',
#   'in',
#   'reaffirm',
#   'the',
#   'great',
#   'of',
#   'our',
#   'nation',
#   ',',
#   'we',
#   'understand',
#   'that',
#   'great',
#   'is',
#   'never',
#   'a',
#   'given',
#   '.',
#   'it',
#   'must',
#   'be',
#   'earn',
#   '.',
#   'our',
#   'journey',
#   'has',
#   'never',
#   'been',
#   'one',
#   'of',
#   'shortcut',
#   'or',
#   'settl',
#   'for',
#   'less',
#   '.',
#   'it',
#   'has',
#   'not',
#   'been',
#   'the',
#   'path',
#   'for',
#   'the',
#   'faint-heart',
#   ',',
#   'for',
#   'those',
#   'who',
#   'prefer',
#   'leisur',
#   'over',
#   'work',
#   ',',
#   'or',
#   'seek',
#   'onli',
#   'the',
#   'pleasur',
#   'of',
#   'rich',
#   'and',
#   'fame',
#   '.',
#   'rather',
#   ',',
#   'it',
#   'has',
#   'been',
#   'the',
#   'risk-tak',
#   ',',
#   'the',
#   'doer',
#   ',',
#   'the',
#   'maker',
#   'of',
#   'thing',
#   '-',
#   'some',
#   'celebr',
#   ',',
#   'but',
#   'more',
#   'often',
#   'men',
#   'and',
#   'women',
#   'obscur',
#   'in',
#   'their',
#   'labor',
#   ',',
#   'who',
#   'have',
#   'carri',
#   'us',
#   'up',
#   'the',
#   'long',
#   ',',
#   'rug',
#   'path',
#   'toward',
#   'prosper',
#   'and',
#   'freedom',
#   '.',
#   'for',
#   'us',
#   ',',
#   'they',
#   'pack',
#   'up',
#   'their',
#   'few',
#   'world',
#   'possess',
#   'and',
#   'travel',
#   'across',
#   'ocean',
#   'in',
#   'search',
#   'of',
#   'a',
#   'new',
#   'life',
#   '.',
#   'for',
#   'us',
#   ',',
#   'they',
#   'toil',
#   'in',
#   'sweatshop',
#   'and',
#   'settl',
#   'the',
#   'west',
#   ';',
#   'endur',
#   'the',
#   'lash',
#   'of',
#   'the',
#   'whip',
#   'and',
#   'plow',
#   'the',
#   'hard',
#   'earth',
#   '.',
#   'for',
#   'us',
#   ',',
#   'they',
#   'fought',
#   'and',
#   'die',
#   ',',
#   'in',
#   'place',
#   'like',
#   'concord',
#   'and',
#   'gettysburg',
#   ';',
#   'normandi',
#   'and',
#   'khe',
#   'sahn',
#   '.',
#   'time',
#   'and',
#   'again',
#   'these',
#   'men',
#   'and',
#   'women',
#   'struggl',
#   'and',
#   'sacrif',
#   'and',
#   'work',
#   'till',
#   'their',
#   'hand',
#   'were',
#   'raw',
#   'so',
#   'that',
#   'we',
#   'might',
#   'live',
#   'a',
#   'better',
#   'life',
#   '.',
#   'they',
#   'saw',
#   'america',
#   'as',
#   'bigger',
#   'than',
#   'the',
#   'sum',
#   'of',
#   'our',
#   'individu',
#   'ambit',
#   ';',
#   'greater',
#   'than',
#   'all',
#   'the',
#   'differ',
#   'of',
#   'birth',
#   'or',
#   'wealth',
#   'or',
#   'faction',
#   '.',
#   'this',
#   'is',
#   'the',
#   'journey',
#   'we',
#   'continu',
#   'today',
#   '.',
#   'we',
#   'remain',
#   'the',
#   'most',
#   'prosper',
#   ',',
#   'power',
#   'nation',
#   'on',
#   'earth',
#   '.',
#   'our',
#   'worker',
#   'are',
#   'no',
#   'less',
#   'product',
#   'than',
#   'when',
#   'this',
#   'crisi',
#   'began',
#   '.',
#   'our',
#   'mind',
#   'are',
#   'no',
#   'less',
#   'invent',
#   ',',
#   'our',
#   'good',
#   'and',
#   'servic',
#   'no',
#   'less',
#   'need',
#   'than',
#   'they',
#   'were',
#   'last',
#   'week',
#   'or',
#   'last',
#   'month',
#   'or',
#   'last',
#   'year',
#   '.',
#   'our',
#   'capac',
#   'remain',
#   'undiminish',
#   '.',
#   'but',
#   'our',
#   'time',
#   'of',
#   'stand',
#   'pat',
#   ',',
#   'of',
#   'protect',
#   'narrow',
#   'interest',
#   'and',
#   'put',
#   'off',
#   'unpleas',
#   'decis',
#   '--',
#   'that',
#   'time',
#   'has',
#   'sure',
#   'pass',
#   '.',
#   'start',
#   'today',
#   ',',
#   'we',
#   'must',
#   'pick',
#   'ourselv',
#   'up',
#   ',',
#   'dust',
#   'ourselv',
#   'off',
#   ',',
#   'and',
#   'begin',
#   'again',
#   'the',
#   'work',
#   'of',
#   'remak',
#   'america',
#   '.',
#   'for',
#   'everywher',
#   'we',
#   'look',
#   ',',
#   'there',
#   'is',
#   'work',
#   'to',
#   'be',
#   'done',
#   '.',
#   'the',
#   'state',
#   'of',
#   'the',
#   'economi',
#   'call',
#   'for',
#   'action',
#   ',',
#   'bold',
#   'and',
#   'swift',
#   ',',
#   'and',
#   'we',
#   'will',
#   'act',
#   'not',
#   'onli',
#   'to',
#   'creat',
#   'new',
#   'job',
#   ',',
#   'but',
#   'to',
#   'lay',
#   'a',
#   'new',
#   'foundat',
#   'for',
#   'growth',
#   '.',
#   'we',
#   'will',
#   'build',
#   'the',
#   'road',
#   'and',
#   'bridg',
#   ',',
#   'the',
#   'electr',
#   'grid',
#   'and',
#   'digit',
#   'line',
#   'that',
#   'feed',
#   'our',
#   'commerc',
#   'and',
#   'bind',
#   'us',
#   'togeth',
#   '.',
#   'we',
#   'will',
#   'restor',
#   'scienc',
#   'to',
#   'it',
#   'right',
#   'place',
#   ',',
#   'and',
#   'wield',
#   'technolog',
#   'wonder',
#   'to',
#   'rais',
#   'healthcar',
#   'qualiti',
#   'and',
#   'lower',
#   'it',
#   'cost',
#   '.',
#   'we',
#   'will',
#   'har',
#   'the',
#   'sun',
#   'and',
#   'the',
#   'wind',
#   'and',
#   'the',
#   'soil',
#   'to',
#   'fuel',
#   'our',
#   'car',
#   'and',
#   'run',
#   'our',
#   'factori',
#   '.',
#   'and',
#   'we',
#   'will',
#   'transform',
#   'our',
#   'school',
#   'and',
#   'colleg',
#   'and',
#   'univers',
#   'to',
#   'meet',
#   'the',
#   'demand',
#   'of',
#   'a',
#   'new',
#   'age',
#   '.',
#   'all',
#   'this',
#   'we',
#   'can',
#   'do',
#   '.',
#   'and',
#   'all',
#   'this',
#   'we',
#   'will',
#   'do',
#   '.',
#   'now',
#   ',',
#   'there',
#   'are',
#   'some',
#   'who',
#   'question',
#   'the',
#   'scale',
#   'of',
#   'our',
#   'ambit',
#   '--',
#   'who',
#   'suggest',
#   'that',
#   'our',
#   'system',
#   'can',
#   'not',
#   'toler',
#   'too',
#   'mani',
#   'big',
#   'plan',
#   '.',
#   'their',
#   'memori',
#   'are',
#   'short',
#   ...],
#  ['chief',
#   'justic',
#   'robert',
#   ',',
#   'presid',
#   'carter',
#   ',',
#   'presid',
#   'clinton',
#   ',',
#   'presid',
#   'bush',
#   ',',
#   'presid',
#   'obama',
#   ',',
#   'fellow',
#   'american',
#   ',',
#   'and',
#   'peopl',
#   'of',
#   'the',
#   'world',
#   ':',
#   'thank',
#   'you',
#   '.',
#   'we',
#   ',',
#   'the',
#   'citizen',
#   'of',
#   'america',
#   ',',
#   'are',
#   'now',
#   'join',
#   'in',
#   'a',
#   'great',
#   'nation',
#   'effort',
#   'to',
#   'rebuild',
#   'our',
#   'countri',
#   'and',
#   'to',
#   'restor',
#   'it',
#   'promis',
#   'for',
#   'all',
#   'of',
#   'our',
#   'peopl',
#   '.',
#   'togeth',
#   ',',
#   'we',
#   'will',
#   'determin',
#   'the',
#   'cours',
#   'of',
#   'america',
#   'and',
#   'the',
#   'world',
#   'for',
#   'year',
#   'to',
#   'come',
#   '.',
#   'we',
#   'will',
#   'face',
#   'challeng',
#   '.',
#   'we',
#   'will',
#   'confront',
#   'hardship',
#   '.',
#   'but',
#   'we',
#   'will',
#   'get',
#   'the',
#   'job',
#   'done',
#   '.',
#   'everi',
#   'four',
#   'year',
#   ',',
#   'we',
#   'gather',
#   'on',
#   'these',
#   'step',
#   'to',
#   'carri',
#   'out',
#   'the',
#   'order',
#   'and',
#   'peac',
#   'transfer',
#   'of',
#   'power',
#   ',',
#   'and',
#   'we',
#   'are',
#   'grate',
#   'to',
#   'presid',
#   'obama',
#   'and',
#   'first',
#   'ladi',
#   'michell',
#   'obama',
#   'for',
#   'their',
#   'gracious',
#   'aid',
#   'throughout',
#   'this',
#   'transit',
#   '.',
#   'they',
#   'have',
#   'been',
#   'magnific',
#   '.',
#   'today',
#   '’',
#   's',
#   'ceremoni',
#   ',',
#   'howev',
#   ',',
#   'has',
#   'veri',
#   'special',
#   'mean',
#   '.',
#   'becaus',
#   'today',
#   'we',
#   'are',
#   'not',
#   'mere',
#   'transfer',
#   'power',
#   'from',
#   'one',
#   'administr',
#   'to',
#   'anoth',
#   ',',
#   'or',
#   'from',
#   'one',
#   'parti',
#   'to',
#   'anoth',
#   '–',
#   'but',
#   'we',
#   'are',
#   'transfer',
#   'power',
#   'from',
#   'washington',
#   ',',
#   'd.c.',
#   'and',
#   'give',
#   'it',
#   'back',
#   'to',
#   'you',
#   ',',
#   'the',
#   'american',
#   'peopl',
#   '.',
#   'for',
#   'too',
#   'long',
#   ',',
#   'a',
#   'small',
#   'group',
#   'in',
#   'our',
#   'nation',
#   '’',
#   's',
#   'capit',
#   'has',
#   'reap',
#   'the',
#   'reward',
#   'of',
#   'govern',
#   'while',
#   'the',
#   'peopl',
#   'have',
#   'born',
#   'the',
#   'cost',
#   '.',
#   'washington',
#   'flourish',
#   '–',
#   'but',
#   'the',
#   'peopl',
#   'did',
#   'not',
#   'share',
#   'in',
#   'it',
#   'wealth',
#   '.',
#   'politician',
#   'prosper',
#   '–',
#   'but',
#   'the',
#   'job',
#   'left',
#   ',',
#   'and',
#   'the',
#   'factori',
#   'close',
#   '.',
#   'the',
#   'establish',
#   'protect',
#   'itself',
#   ',',
#   'but',
#   'not',
#   'the',
#   'citizen',
#   'of',
#   'our',
#   'countri',
#   '.',
#   'their',
#   'victori',
#   'have',
#   'not',
#   'been',
#   'your',
#   'victori',
#   ';',
#   'their',
#   'triumph',
#   'have',
#   'not',
#   'been',
#   'your',
#   'triumph',
#   ';',
#   'and',
#   'while',
#   'they',
#   'celebr',
#   'in',
#   'our',
#   'nation',
#   '’',
#   's',
#   'capit',
#   ',',
#   'there',
#   'was',
#   'littl',
#   'to',
#   'celebr',
#   'for',
#   'struggl',
#   'famili',
#   'all',
#   'across',
#   'our',
#   'land',
#   '.',
#   'that',
#   'all',
#   'chang',
#   '–',
#   'start',
#   'right',
#   'here',
#   ',',
#   'and',
#   'right',
#   'now',
#   ',',
#   'becaus',
#   'this',
#   'moment',
#   'is',
#   'your',
#   'moment',
#   ':',
#   'it',
#   'belong',
#   'to',
#   'you',
#   '.',
#   'it',
#   'belong',
#   'to',
#   'everyon',
#   'gather',
#   'here',
#   'today',
#   'and',
#   'everyon',
#   'watch',
#   'all',
#   'across',
#   'america',
#   '.',
#   'this',
#   'is',
#   'your',
#   'day',
#   '.',
#   'this',
#   'is',
#   'your',
#   'celebr',
#   '.',
#   'and',
#   'this',
#   ',',
#   'the',
#   'unit',
#   'state',
#   'of',
#   'america',
#   ',',
#   'is',
#   'your',
#   'countri',
#   '.',
#   'what',
#   'truli',
#   'matter',
#   'is',
#   'not',
#   'which',
#   'parti',
#   'control',
#   'our',
#   'govern',
#   ',',
#   'but',
#   'whether',
#   'our',
#   'govern',
#   'is',
#   'control',
#   'by',
#   'the',
#   'peopl',
#   '.',
#   'januari',
#   '20th',
#   '2017',
#   ',',
#   'will',
#   'be',
#   'rememb',
#   'as',
#   'the',
#   'day',
#   'the',
#   'peopl',
#   'becam',
#   'the',
#   'ruler',
#   'of',
#   'this',
#   'nation',
#   'again',
#   '.',
#   'the',
#   'forgotten',
#   'men',
#   'and',
#   'women',
#   'of',
#   'our',
#   'countri',
#   'will',
#   'be',
#   'forgotten',
#   'no',
#   'longer',
#   '.',
#   'everyon',
#   'is',
#   'listen',
#   'to',
#   'you',
#   'now',
#   '.',
#   'you',
#   'came',
#   'by',
#   'the',
#   'ten',
#   'of',
#   'million',
#   'to',
#   'becom',
#   'part',
#   'of',
#   'a',
#   'histor',
#   'movement',
#   'the',
#   'like',
#   'of',
#   'which',
#   'the',
#   'world',
#   'has',
#   'never',
#   'seen',
#   'befor',
#   '.',
#   'at',
#   'the',
#   'center',
#   'of',
#   'this',
#   'movement',
#   'is',
#   'a',
#   'crucial',
#   'convict',
#   ':',
#   'that',
#   'a',
#   'nation',
#   'exist',
#   'to',
#   'serv',
#   'it',
#   'citizen',
#   '.',
#   'american',
#   'want',
#   'great',
#   'school',
#   'for',
#   'their',
#   'children',
#   ',',
#   'safe',
#   'neighborhood',
#   'for',
#   'their',
#   'famili',
#   ',',
#   'and',
#   'good',
#   'job',
#   'for',
#   'themselv',
#   '.',
#   'these',
#   'are',
#   'the',
#   'just',
#   'and',
#   'reason',
#   'demand',
#   'of',
#   'a',
#   'righteous',
#   'public',
#   '.',
#   'but',
#   'for',
#   'too',
#   'mani',
#   'of',
#   'our',
#   'citizen',
#   ',',
#   'a',
#   'differ',
#   'realiti',
#   'exist',
#   ':',
#   'mother',
#   'and',
#   'children',
#   'trap',
#   'in',
#   'poverti',
#   'in',
#   'our',
#   'inner',
#   'citi',
#   ';',
#   'rusted-out',
#   'factori',
#   'scatter',
#   'like',
#   'tombston',
#   'across',
#   'the',
#   'landscap',
#   'of',
#   'our',
#   'nation',
#   ';',
#   'an',
#   'educ',
#   'system',
#   ',',
#   'flush',
#   'with',
#   'cash',
#   ',',
#   'but',
#   'which',
#   'leav',
#   'our',
#   'young',
#   'and',
#   'beauti',
#   'student',
#   'depriv',
#   'of',
#   'knowledg',
#   ';',
#   'and',
#   'the',
#   'crime',
#   'and',
#   'gang',
#   'and',
#   'drug',
#   'that',
#   'have',
#   'stolen',
#   'too',
#   'mani',
#   'live',
#   'and',
#   'rob',
#   'our',
#   'countri',
#   'of',
#   'so',
#   'much',
#   'unreal',
#   'potenti',
#   '.',
#   'this',
#   'american',
#   'carnag',
#   'stop',
#   'right',
#   'here',
#   'and',
#   'stop',
#   'right',
#   'now',
#   '.',
#   'we',
#   'are',
#   'one',
#   'nation',
#   '–',
#   'and',
#   'their',
#   'pain',
#   'is',
#   'our',
#   'pain',
#   '.',
#   'their',
#   'dream',
#   'are',
#   'our',
#   'dream',
#   ';',
#   'and',
#   'their',
#   'success',
#   'will',
#   'be',
#   'our',
#   'success',
#   '.',
#   'we',
#   'share',
#   'one',
#   'heart',
#   ',',
#   'one',
#   'home',
#   ',',
#   'and',
#   'one',
#   'glorious',
#   'destini',
#   '.',
#   'the',
#   'oath',
#   'of',
#   'offic',
#   'i',
#   'take',
#   'today',
#   'is',
#   'an',
#   'oath',
#   'of',
#   'allegi',
#   'to',
#   'all',
#   'american',
#   '.',
#   'for',
#   'mani',
#   'decad',
#   ',',
#   'we',
#   '’',
#   've',
#   'enrich',
#   'foreign',
#   'industri',
#   'at',
#   'the',
#   'expens',
#   'of',
#   'american',
#   'industri',
#   ';',
#   'subsid',
#   'the',
#   'armi',
#   'of',
#   'other',
#   'countri',
#   'while',
#   'allow',
#   'for',
#   'the',
#   'veri',
#   'sad',
#   'deplet',
#   'of',
#   'our',
#   'militari',
#   ';',
#   'we',
#   '’',
#   've',
#   'defend',
#   'other',
#   'nation',
#   '’',
#   's',
#   'border',
#   'while',
#   'refus',
#   'to',
#   'defend',
#   'our',
#   'own',
#   ';',
#   'and',
#   'spent',
#   'trillion',
#   'of',
#   'dollar',
#   'oversea',
#   'while',
#   'america',
#   '’',
#   's',
#   'infrastructur',
#   'has',
#   'fallen',
#   'into',
#   'disrepair',
#   'and',
#   'decay',
#   '.',
#   'we',
#   '’',
#   've',
#   'made',
#   'other',
#   'countri',
#   'rich',
#   'while',
#   'the',
#   'wealth',
#   ',',
#   'strength',
#   ',',
#   'and',
#   'confid',
#   'of',
#   'our',
#   'countri',
#   'has',
#   'disappear',
#   'over',
#   'the',
#   'horizon',
#   '.',
#   'one',
#   'by',
#   'one',
#   ',',
#   'the',
#   'factori',
#   'shutter',
#   'and',
#   'left',
#   'our',
#   'shore',
#   ',',
#   'with',
#   'not',
#   'even',
#   'a',
#   'thought',
#   'about',
#   'the',
#   'million',
#   'upon',
#   'million',
#   'of',
#   'american',
#   'worker',
#   'left',
#   'behind',
#   '.',
#   'the',
#   'wealth',
#   'of',
#   'our',
#   'middl',
#   'class',
#   'has',
#   'been',
#   'rip',
#   'from',
#   'their',
#   'home',
#   'and',
#   'then',
#   'redistribut',
#   'across',
#   'the',
#   'entir',
#   'world',
#   '.',
#   'but',
#   'that',
#   'is',
#   'the',
#   'past',
#   '.',
#   'and',
#   'now',
#   'we',
#   'are',
#   'look',
#   'onli',
#   'to',
#   'the',
#   'futur',
#   '.',
#   'we',
#   'assembl',
#   'here',
#   'today',
#   'are',
#   'issu',
#   'a',
#   'new',
#   'decre',
#   'to',
#   'be',
#   'heard',
#   'in',
#   'everi',
#   'citi',
#   ',',
#   'in',
#   'everi',
#   'foreign',
#   'capit',
#   ',',
#   'and',
#   'in',
#   'everi',
#   'hall',
#   'of',
#   'power',
#   '.',
#   'from',
#   'this',
#   'day',
#   'forward',
#   ',',
#   'a',
#   'new',
#   'vision',
#   'will',
#   'govern',
#   'our',
#   'land',
#   '.',
#   'from',
#   'this',
#   'moment',
#   'on',
#   ',',
#   'it',
#   '’',
#   's',
#   'go',
#   'to',
#   'be',
#   'america',
#   'first',
#   '.',
#   'everi',
#   'decis',
#   'on',
#   'trade',
#   ',',
#   'on',
#   'tax',
#   ',',
#   'on',
#   'immigr',
#   ',',
#   'on',
#   'foreign',
#   'affair',
#   ',',
#   'will',
#   'be',
#   'made',
#   'to',
#   'benefit',
#   'american',
#   'worker',
#   'and',
#   'american',
#   'famili',
#   '.',
#   'we',
#   'must',
#   'protect',
#   'our',
#   'border',
#   'from',
#   'the',
#   'ravag',
#   'of',
#   'other',
#   'countri',
#   'make',
#   'our',
#   'product',
#   ',',
#   'steal',
#   'our',
#   'compani',
#   ',',
#   'and',
#   'destroy',
#   'our',
#   'job',
#   '.',
#   'protect',
#   'will',
#   'lead',
#   'to',
#   'great',
#   'prosper',
#   'and',
#   'strength',
#   '.',
#   'i',
#   'will',
#   'fight',
#   'for',
#   'you',
#   'with',
#   'everi',
#   'breath',
#   'in',
#   'my',
#   'bodi',
#   '–',
#   'and',
#   'i',
#   'will',
#   'never',
#   ',',
#   'ever',
#   'let',
#   'you',
#   'down',
#   '.',
#   'america',
#   'will',
#   'start',
#   'win',
#   'again',
#   ',',
#   'win',
#   'like',
#   'never',
#   'befor',
#   '.',
#   'we',
#   'will',
#   'bring',
#   'back',
#   'our',
#   'job',
#   '.',
#   'we',
#   'will',
#   'bring',
#   'back',
#   'our',
#   'border',
#   '.',
#   'we',
#   'will',
#   'bring',
#   'back',
#   'our',
#   'wealth',
#   '.',
#   'and',
#   'we',
#   'will',
#   'bring',
#   'back',
#   'our',
#   'dream',
#   '.',
#   'we',
#   'will',
#   'build',
#   'new',
#   'road',
#   ',',
#   'and',
#   'highway',
#   ',',
#   'and',
#   'bridg',
#   ',',
#   'and',
#   'airport',
#   ',',
#   'and',
#   'tunnel',
#   ',',
#   'and',
#   'railway',
#   'all',
#   'across',
#   'our',
#   'wonder',
#   'nation',
#   '.',
#   ...]]

# %%
speeches_cleaned[3] = speeches_cleaned[3][:-5]

# %%
import string

# %%
stops = nltk.corpus.stopwords.words('english')
stops.extend(list(string.punctuation))
stops.extend(list(string.digits))

corpus = []
for speech in speeches_cleaned:
    cleaned = []
    for word in speech:
        if word not in stops and not word.isnumeric():
            cleaned.append(word)
    corpus.append(cleaned)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()
cv.fit([' '.join(speech) for speech in corpus])
# Out:
# CountVectorizer()

# %%
X = cv.transform([' '.join(speech) for speech in corpus])

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import ComplementNB, MultinomialNB

# %%
cnb = ComplementNB().fit(X, y_train)

# %%
cnb.score(X, y_train)
# Out:
# 1.0

# %%
stem = nltk.stem.SnowballStemmer('english')

test_cleaned = [[stem.stem(word.lower())
                     for word in nltk.word_tokenize(speech.replace('\'', ''))]\
                     for speech in X_test]

# %%
stops = nltk.corpus.stopwords.words('english')
stops.extend(list(string.punctuation))
stops.extend(list(string.digits))

testcorpus = []
for speech in test_cleaned:
    cleaned = []
    for word in speech:
        if word not in stops and not word.isnumeric():
            cleaned.append(word)
    testcorpus.append(cleaned)

# %%
Xtest = cv.transform([' '.join(speech) for speech in testcorpus])

# %%
cnb.score(Xtest, y_test)
# Out:
# 0.5909090909090909

# %%
mnb = MultinomialNB(alpha=0.01)

# %%
mnb.fit(X, y_train)
# Out:
# MultinomialNB(alpha=0.01)

# %%
mnb.score(Xtest, y_test)
# Out:
# 0.5454545454545454

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
svc = SVC().fit(X, y_train)

# %%
svc.score(Xtest, y_test)
# Out:
# 0.45454545454545453

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression().fit(X, y_train)
# Out:
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
logreg.score(Xtest, y_test)
# Out:
# 0.5454545454545454

# %% [markdown]
# ## GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
cnb_grid = {
    'norm': [True, False],
    'alpha': [1, 0.1, 0.01]
}

# %%
gs_cnb = GridSearchCV(ComplementNB(), cnb_grid)
gs_cnb.fit(X, y_train)
# Out:
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# GridSearchCV(estimator=ComplementNB(),
#              param_grid={'alpha': [1, 0.1, 0.01], 'norm': [True, False]})

# %%
gs_cnb.best_params_
# Out:
# {'alpha': 1, 'norm': True}

# %%
gs_cnb.score(Xtest, y_test)
# Out:
# 0.5454545454545454

# %%
mnb_grid = {
    'alpha': [1, 0.1, 0.01]
}

# %%
gs_mnb = GridSearchCV(MultinomialNB(), mnb_grid)
gs_mnb.fit(X, y_train)
# Out:
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# GridSearchCV(estimator=MultinomialNB(), param_grid={'alpha': [1, 0.1, 0.01]})

# %%
gs_mnb.best_params_
# Out:
# {'alpha': 1}

# %%
gs_mnb.score(Xtest, y_test)
# Out:
# 0.5454545454545454

# %%
svc_grid = {
    'C': [10, 1, 0.1],
    'kernel': ['poly', 'rbf', 'sigmoid'],
    'degree': [2, 3 ,4],
    'gamma': ['scale', 'auto'],
    'probability': [True, False]
}

# %%
gs_svc = GridSearchCV(SVC(), svc_grid)
gs_svc.fit(X, y_train)
# Out:
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [10, 1, 0.1], 'degree': [2, 3, 4],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['poly', 'rbf', 'sigmoid'],
#                          'probability': [True, False]})

# %%
gs_svc.best_params_
# Out:
# {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly', 'probability': True}

# %%
gs_svc.score(Xtest, y_test)
# Out:
# 0.6363636363636364

# %%
svc_grid2 = {
    'C': [1, 5, 10, 100],
    'degree': [0, 1, 2],
    'kernel': ['poly', 'linear']
}

# %%
gs_svc2 = GridSearchCV(SVC(gamma='auto',
                          probability=True), svc_grid2)
gs_svc2.fit(X, y_train)
# Out:
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# GridSearchCV(estimator=SVC(gamma='auto', probability=True),
#              param_grid={'C': [1, 5, 10, 100], 'degree': [0, 1, 2],
#                          'kernel': ['poly', 'linear']})

# %%
gs_svc2.best_params_
# Out:
# {'C': 5, 'degree': 2, 'kernel': 'poly'}

# %%
gs_svc2.score(Xtest, y_test)
# Out:
# 0.5909090909090909

# %%
logreg_grid = {
    'penalty': ['l1', 'l2'],
    'C': [10, 1, 0.1],
    'class_weight': [None, 'balanced']
}

# %%
gs_logreg = GridSearchCV(LogisticRegression(max_iter=1e4,
                                           solver='liblinear'), logreg_grid)
gs_logreg.fit(X, y_train)
# Out:
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# GridSearchCV(estimator=LogisticRegression(max_iter=10000.0, solver='liblinear'),
#              param_grid={'C': [10, 1, 0.1], 'class_weight': [None, 'balanced'],
#                          'penalty': ['l1', 'l2']})

# %%
gs_logreg.best_params_
# Out:
# {'C': 0.1, 'class_weight': None, 'penalty': 'l2'}

# %%
logreg_grid2 = {
    'C': [0.5, 0.1, 0.01]
}

# %%
gs_logreg2 = GridSearchCV(LogisticRegression(max_iter=1e4,
                                            solver='liblinear'),
                         logreg_grid2)
gs_logreg2.fit(X, y_train)
# Out:
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# GridSearchCV(estimator=LogisticRegression(max_iter=10000.0, solver='liblinear'),
#              param_grid={'C': [0.5, 0.1, 0.01]})

# %%
gs_logreg2.best_params_
# Out:
# {'C': 0.1}

# %%
gs_logreg.score(Xtest, y_test)
# Out:
# 0.5

# %% [markdown]
# ## Voting and Stacking

# %%
from sklearn.ensemble import VotingClassifier, StackingClassifier

# %%
vc = VotingClassifier(estimators=[
    ('mnb', gs_mnb),
    ('cnb', gs_cnb),
    ('svc', gs_svc),
    ('logreg', gs_logreg)
])

# %%
vc.fit(X, y_train)
# Out:
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# VotingClassifier(estimators=[('mnb',
#                               GridSearchCV(estimator=MultinomialNB(),
#                                            param_grid={'alpha': [1, 0.1,
#                                                                  0.01]})),
#                              ('cnb',
#                               GridSearchCV(estimator=ComplementNB(),
#                                            param_grid={'alpha': [1, 0.1, 0.01],
#                                                        'norm': [True, False]})),
#                              ('svc',
#                               GridSearchCV(estimator=SVC(),
#                                            param_grid={'C': [10, 1, 0.1],
#                                                        'degree': [2, 3, 4],
#                                                        'gamma': ['scale',
#                                                                  'auto'],
#                                                        'kernel': ['poly', 'rbf',
#                                                                   'sigmoid'],
#                                                        'probability': [True,
#                                                                        False]})),
#                              ('logreg',
#                               GridSearchCV(estimator=LogisticRegression(max_iter=10000.0,
#                                                                         solver='liblinear'),
#                                            param_grid={'C': [10, 1, 0.1],
#                                                        'class_weight': [None,
#                                                                         'balanced'],
#                                                        'penalty': ['l1',
#                                                                    'l2']}))])

# %%
vc.score(Xtest, y_test)
# Out:
# 0.6363636363636364

# %%
sc = StackingClassifier(estimators=[
    ('mnb', gs_mnb),
    ('cnb', gs_cnb),
    ('svc', gs_svc),
    ('logreg', gs_logreg)
])

# %%
sc.fit(X, y_train)
# Out:
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:905: RuntimeWarning: Number of classes in training fold (4) does not match total number of classes (5). Results may not be appropriate for your use case. To fix this, use a cross-validation technique resulting in properly stratified folds
#   RuntimeWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:905: RuntimeWarning: Number of classes in training fold (4) does not match total number of classes (5). Results may not be appropriate for your use case. To fix this, use a cross-validation technique resulting in properly stratified folds
#   RuntimeWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:905: RuntimeWarning: Number of classes in training fold (4) does not match total number of classes (5). Results may not be appropriate for your use case. To fix this, use a cross-validation technique resulting in properly stratified folds
#   RuntimeWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:905: RuntimeWarning: Number of classes in training fold (4) does not match total number of classes (5). Results may not be appropriate for your use case. To fix this, use a cross-validation technique resulting in properly stratified folds
#   RuntimeWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /Users/gdamico/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# StackingClassifier(estimators=[('mnb',
#                                 GridSearchCV(estimator=MultinomialNB(),
#                                              param_grid={'alpha': [1, 0.1,
#                                                                    0.01]})),
#                                ('cnb',
#                                 GridSearchCV(estimator=ComplementNB(),
#                                              param_grid={'alpha': [1, 0.1,
#                                                                    0.01],
#                                                          'norm': [True,
#                                                                   False]})),
#                                ('svc',
#                                 GridSearchCV(estimator=SVC(),
#                                              param_grid={'C': [10, 1, 0.1],
#                                                          'degree': [2, 3, 4],
#                                                          'gamma': ['scale',
#                                                                    'auto'],
#                                                          'kernel': ['poly',
#                                                                     'rbf',
#                                                                     'sigmoid'],
#                                                          'probability': [True,
#                                                                          False]})),
#                                ('logreg',
#                                 GridSearchCV(estimator=LogisticRegression(max_iter=10000.0,
#                                                                           solver='liblinear'),
#                                              param_grid={'C': [10, 1, 0.1],
#                                                          'class_weight': [None,
#                                                                           'balanced'],
#                                                          'penalty': ['l1',
#                                                                      'l2']}))])

# %%
sc.score(Xtest, y_test)
# Out:
# 0.5454545454545454

# %% [markdown]
# ***

# %% [markdown]
# ## Preparing for Pickling

# %%
import pandas as pd
import numpy as np
traindf = pd.DataFrame(zip(X_train, y_train))

# %%
X_train = traindf.sample(frac=1, random_state=42)[0]

# %%
y_train = traindf.sample(frac=1, random_state=42)[1]

# %%
testdf = pd.DataFrame(zip(X_test, y_test))

# %%
X_test = testdf.sample(frac=1, random_state=42)[0]

# %%
y_test = testdf.sample(frac=1, random_state=42)[1]

# %%
with open('X_train.pkl', 'wb') as f:
    pickle.dump(X_train, f)

# %%
with open('y_train.pkl', 'wb') as f:
    pickle.dump(y_train, f)

# %%
with open('X_test.pkl', 'wb') as f:
    pickle.dump(X_test, f)

# %%
with open('y_test.pkl', 'wb') as f:
    pickle.dump(y_test, f)

# %%
with open('voting_model.pkl', 'wb') as f:
    pickle.dump(vc, f)
